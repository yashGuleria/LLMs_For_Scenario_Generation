# %%
import pandas as pd
import numpy as np
from pathlib import Path
from typing import List, Dict, Tuple
from dataclasses import dataclass

aircraft_speeds = {}

@dataclass
class Cell4D:
    """Represents a 4D airspace cell"""
    x_min: float  
    x_max: float
    y_min: float  
    y_max: float
    z_min: float  
    z_max: float
    t_min: int    
    t_max: int
    aircraft_records: List[Dict]

class ComplexityCalculator:
    def __init__(self, 
                 cell_size_nm: float = 20.0,
                 cell_height_ft: float = 3000.0,
                 time_step_min: float = 10.0):
        
        self.cell_size_nm = cell_size_nm
        self.cell_height_ft = cell_height_ft
        self.time_step_sec = time_step_min * 1
        self.cells: Dict[Tuple, Cell4D] = {}
        
    def _determine_vertical_state(self, alt1: float, alt2: float, time_diff: float) -> str:
        """Determine if aircraft is climbing, cruising, or descending"""
        VERTICAL_RATE_THRESHOLD = 500.0  # ft/min
        
        # Convert threshold to per second
        threshold_per_sec = VERTICAL_RATE_THRESHOLD / 60 
        alt_diff = alt2 - alt1
        rate = alt_diff / time_diff if time_diff > 0 else 0
        
        if abs(rate) < threshold_per_sec:
            return "cruise"
        return "climb" if rate > 0 else "descent"
    
    def _check_temporal_overlap(self, ac1: Dict, ac2: Dict) -> float:
        """
        Calculate the duration of temporal overlap between two aircraft in a cell
        Returns overlap duration in hours
        """
        start1, end1 = ac1['entry_time'], ac1['exit_time']
        start2, end2 = ac2['entry_time'], ac2['exit_time']
        
        # Calculate overlap
        overlap_start = max(start1, start2)
        overlap_end = min(end1, end2)
        
        if overlap_end > overlap_start:
            return (overlap_end - overlap_start) / 3600  # Convert to hours
        return 0
    
    
    def _extract_aircraft_type(self, flight_id: str) -> str:
        """Extract aircraft type from flight ID (e.g., 'SQ10_B738_trajectory' -> 'B738')"""
        parts = flight_id.split('_')
        if len(parts) > 1:
            return parts[1]
        return ''

    def create_4d_grid(self, all_data: pd.DataFrame) -> None:
        """Create 4D grid and assign aircraft to cells"""
        # Find bounds of the airspace
        lat_min, lat_max = all_data['latitude'].min(), all_data['latitude'].max()
        lon_min, lon_max = all_data['longitude'].min(), all_data['longitude'].max()
        alt_min, alt_max = all_data['altitude'].min(), all_data['altitude'].max()
        time_min, time_max = all_data['timestamp'].min(), all_data['timestamp'].max()

        # Create grid edges
        lat_edges = np.arange(lat_min, lat_max + self.cell_size_nm/60, self.cell_size_nm/60)
        lon_edges = np.arange(lon_min, lon_max + self.cell_size_nm/60, self.cell_size_nm/60)
        alt_edges = np.arange(alt_min, alt_max + self.cell_height_ft, self.cell_height_ft)
        time_edges = np.arange(time_min, time_max + self.time_step_sec, self.time_step_sec)

        # Group data by flight_id to process each trajectory
        for flight_id, flight_data in all_data.groupby('flight_id'):
            flight_data = flight_data.sort_values('timestamp')
            aircraft_type = self._extract_aircraft_type(flight_id)
            
            for idx in range(len(flight_data)-1):
                row = flight_data.iloc[idx]
                next_row = flight_data.iloc[idx + 1]
                
                # Find cell indices
                cell_x = np.digitize(row['longitude'], lon_edges) - 1
                cell_y = np.digitize(row['latitude'], lat_edges) - 1
                cell_z = np.digitize(row['altitude'], alt_edges) - 1
                cell_t = np.digitize(row['timestamp'], time_edges) - 1
                
                cell_key = (cell_x, cell_y, cell_z, cell_t)
                
                if cell_key not in self.cells:
                    self.cells[cell_key] = Cell4D(
                        x_min=lon_edges[cell_x], x_max=lon_edges[cell_x + 1],
                        y_min=lat_edges[cell_y], y_max=lat_edges[cell_y + 1],
                        z_min=alt_edges[cell_z], z_max=alt_edges[cell_z + 1],
                        t_min=time_edges[cell_t], t_max=time_edges[cell_t + 1],
                        aircraft_records=[]
                    )
                
                time_diff = next_row['timestamp'] - row['timestamp']
                
                # Store aircraft record with entry and exit times
                self.cells[cell_key].aircraft_records.append({
                    'flight_id': flight_id,
                    'aircraft_type': aircraft_type,
                    'entry_time': row['timestamp'],
                    'exit_time': min(next_row['timestamp'], time_edges[cell_t + 1]),
                    'altitude': row['altitude'],
                    'waypoint_segment': row['waypoint_segment'],
                    'heading': np.arctan2(next_row['longitude'] - row['longitude'],
                                        next_row['latitude'] - row['latitude']),
                    'vertical_state': self._determine_vertical_state(
                        row['altitude'], 
                        next_row['altitude'],
                        time_diff
                    )
                })

    def calculate_complexity_metrics(self) -> Dict:
        """Calculate complexity metrics for the airspace"""
        total_flight_hours = 0
        total_interaction_hours = 0
        vertical_interaction_hours = 0
        horizontal_interaction_hours = 0
        speed_interaction_hours = 0
        
        for cell in self.cells.values():
            n_aircraft = len(cell.aircraft_records)
            if n_aircraft < 2:
                if n_aircraft == 1:
                    ac = cell.aircraft_records[0]
                    time_in_cell = (ac['exit_time'] - ac['entry_time']) / 3600
                    total_flight_hours += time_in_cell
                continue
            
            # Calculate interactions between aircraft pairs in the cell
            for i in range(n_aircraft):
                ac1 = cell.aircraft_records[i]
                time_in_cell = (ac1['exit_time'] - ac1['entry_time']) / 3600
                total_flight_hours += time_in_cell
                
                for j in range(i + 1, n_aircraft):
                    ac2 = cell.aircraft_records[j]
                    
                    # Calculate actual temporal overlap
                    interaction_time = self._check_temporal_overlap(ac1, ac2)
                    
                    if interaction_time > 0:
                        total_interaction_hours += interaction_time
                        
                        # Vertical interactions
                        if ac1['vertical_state'] != ac2['vertical_state']:
                            vertical_interaction_hours += interaction_time
                        
                        # Horizontal interactions (heading difference > 20 degrees)
                        heading_diff = abs(ac1['heading'] - ac2['heading'])
                        heading_diff = min(heading_diff, 2*np.pi - heading_diff)
                        if heading_diff > np.radians(20):
                            horizontal_interaction_hours += interaction_time
                     
                        # Speed interactions (different aircraft types)
                        if ac1['aircraft_type'] != ac2['aircraft_type']:
                            speed_interaction_hours += interaction_time   
                        # Speed interactions (different vertical states or altitude separation)
                        # if (ac1['vertical_state'] != ac2['vertical_state'] or 
                        #     abs(ac1['altitude'] - ac2['altitude']) > 1000):
                        #     speed_interaction_hours += interaction_time
                            
            # for i in range(n_aircraft):
            #     ac1 = cell.aircraft_records[i]
            #     time_in_cell = (ac1['exit_time'] - ac1['entry_time']) / 3600
            #     total_flight_hours += time_in_cell
                
            #     for j in range(i + 1, n_aircraft):
            #         ac2 = cell.aircraft_records[j]
                    
            #         # Calculate interaction duration
            #         interaction_time = self._check_temporal_overlap(ac1, ac2)
                    
            #         if interaction_time > 0:
            #             total_interaction_hours += interaction_time
                    
            #         # Vertical interactions
            #         if ac1['vertical_state'] != ac2['vertical_state']:
            #             vertical_interaction_hours += interaction_time
                    
            #         # Horizontal interactions (different waypoint segments)
            #         if ac1['waypoint_segment'] != ac2['waypoint_segment']:
            #             horizontal_interaction_hours += interaction_time
                    
            #         # Speed interactions (based on altitude difference)
            #         if abs(ac1['altitude'] - ac2['altitude']) > 1000:
            #             speed_interaction_hours += interaction_time
        
        # Calculate metrics
        adjusted_density = total_interaction_hours / total_flight_hours if total_flight_hours > 0 else 0
        
        # Calculate relative indicators
        r_vdif = vertical_interaction_hours / total_interaction_hours if total_interaction_hours > 0 else 0
        r_hdif = horizontal_interaction_hours / total_interaction_hours if total_interaction_hours > 0 else 0
        r_sdif = speed_interaction_hours / total_interaction_hours if total_interaction_hours > 0 else 0
        
        # Calculate structural index and complexity score
        structural_index = r_vdif + r_hdif + r_sdif
        complexity_score = adjusted_density * structural_index
        
        return {
            'adjusted_density': adjusted_density,
            'vertical_interactions_per_flight_hour': vertical_interaction_hours / total_flight_hours,
            'horizontal_interactions_per_flight_hour': horizontal_interaction_hours / total_flight_hours,
            'speed_interactions_per_flight_hour': speed_interaction_hours / total_flight_hours,
            'r_vdif': r_vdif,
            'r_hdif': r_hdif,
            'r_sdif': r_sdif,
            'structural_index': structural_index,
            'complexity_score': complexity_score,
            'total_flight_hours': total_flight_hours,
            'number_of_cells': len(self.cells)
        }


def calculate_airspace_complexity(trajectories_folder: str = 'aircraft_trajectories_24jan') -> Dict:
    """
    Calculate airspace complexity from all trajectory files in the specified folder
    """
    # Get all trajectory files from the folder
    trajectory_path = Path(trajectories_folder)
    trajectory_files = list(trajectory_path.glob("SQ*.csv"))
    
    if not trajectory_files:
        raise ValueError(f"No trajectory files found in {trajectories_folder}")
    
    print(f"Found {len(trajectory_files)} trajectory files")
    
    # Read all trajectories into a single DataFrame
    all_data = []
    for file in trajectory_files:
        print(f"Reading {file.name}")
        df = pd.read_csv(file)
        df['flight_id'] = file.stem  # Add flight ID from filename
        all_data.append(df)
    # print(all_data.grouby('flight_id'))
    # Combine all trajectories
    all_trajectories = pd.concat(all_data, ignore_index=True)
    print(f"Total data points: {len(all_trajectories)}")
    
    # Initialize calculator and process data
    calculator = ComplexityCalculator()
    calculator.create_4d_grid(all_trajectories)
    metrics = calculator.calculate_complexity_metrics()
    
    return metrics

# %%
trajectory_path = Path('aircraft_trajectories')
trajectory_files = list(trajectory_path.glob("SQ*.csv"))
all_data = []
for file in trajectory_files:
    print(f"Reading {file.name}")
    df = pd.read_csv(file)
    df['flight_id'] = file.stem  # Add flight ID from filename
    all_data.append(df)
    
all_trajectories = pd.concat(all_data, ignore_index=True)
c = ComplexityCalculator()
c.create_4d_grid(all_trajectories)
# Out:
# Reading SQ17_B738_trajectory.csv
# Reading SQ115_B738_trajectory.csv
# Reading SQ14_B734_trajectory.csv
# Reading SQ114_B738_trajectory.csv
# Reading SQ19_B744_trajectory.csv
# Reading SQ111_B744_trajectory.csv
# Reading SQ112_B744_trajectory.csv
# Reading SQ13_B734_trajectory.csv
# Reading SQ18_B738_trajectory.csv
# Reading SQ116_B738_trajectory.csv
# Reading SQ15_B738_trajectory.csv
# Reading SQ11_B738_trajectory.csv
# Reading SQ113_B738_trajectory.csv
# Reading SQ16_B738_trajectory.csv
# Reading SQ12_B734_trajectory.csv
# Reading SQ10_B738_trajectory.csv
# Reading SQ110_B744_trajectory.csv

# %%
type(c.cells)
# Out:
# dict

# %%
first_key, first_value = next(iter(c.cells.items()))
print(f"First key: {first_key}, First value: {first_value}")
# Out:
# First key: (np.int64(3), np.int64(0), np.int64(7), np.int64(0)), First value: Cell4D(x_min=np.float64(103.67194399999998), x_max=np.float64(104.00527733333331), y_min=np.float64(2.161111), y_max=np.float64(2.4944443333333335), z_min=np.float64(37333.330000000016), z_max=np.float64(40333.330000000016), t_min=np.float64(0.0), t_max=np.float64(3600.0), aircraft_records=[{'flight_id': 'SQ10_B738_trajectory', 'timestamp': np.int64(300), 'altitude': np.float64(39637.0), 'waypoint_segment': 'VMR-LENDA', 'vertical_state': 'descent', 'time_in_cell': np.float64(3300.0)}, {'flight_id': 'SQ10_B738_trajectory', 'timestamp': np.int64(310), 'altitude': np.float64(39274.0), 'waypoint_segment': 'VMR-LENDA', 'vertical_state': 'descent', 'time_in_cell': np.float64(3290.0)}, {'flight_id': 'SQ10_B738_trajectory', 'timestamp': np.int64(320), 'altitude': np.float64(38911.0), 'waypoint_segment': 'VMR-LENDA', 'vertical_state': 'descent', 'time_in_cell': np.float64(3280.0)}, {'flight_id': 'SQ10_B738_trajectory', 'timestamp': np.int64(330), 'altitude': np.float64(38548.0), 'waypoint_segment': 'VMR-LENDA', 'vertical_state': 'descent', 'time_in_cell': np.float64(3270.0)}, {'flight_id': 'SQ10_B738_trajectory', 'timestamp': np.int64(340), 'altitude': np.float64(38185.0), 'waypoint_segment': 'VMR-LENDA', 'vertical_state': 'descent', 'time_in_cell': np.float64(3260.0)}, {'flight_id': 'SQ10_B738_trajectory', 'timestamp': np.int64(350), 'altitude': np.float64(37822.0), 'waypoint_segment': 'VMR-LENDA', 'vertical_state': 'descent', 'time_in_cell': np.float64(3250.0)}, {'flight_id': 'SQ10_B738_trajectory', 'timestamp': np.int64(360), 'altitude': np.float64(37459.0), 'waypoint_segment': 'VMR-LENDA', 'vertical_state': 'descent', 'time_in_cell': np.float64(3240.0)}, {'flight_id': 'SQ11_B738_trajectory', 'timestamp': np.int64(550), 'altitude': np.float64(39637.0), 'waypoint_segment': 'VMR-LENDA', 'vertical_state': 'descent', 'time_in_cell': np.float64(3050.0)}, {'flight_id': 'SQ11_B738_trajectory', 'timestamp': np.int64(560), 'altitude': np.float64(39274.0), 'waypoint_segment': 'VMR-LENDA', 'vertical_state': 'descent', 'time_in_cell': np.float64(3040.0)}, {'flight_id': 'SQ11_B738_trajectory', 'timestamp': np.int64(570), 'altitude': np.float64(38911.0), 'waypoint_segment': 'VMR-LENDA', 'vertical_state': 'descent', 'time_in_cell': np.float64(3030.0)}, {'flight_id': 'SQ11_B738_trajectory', 'timestamp': np.int64(580), 'altitude': np.float64(38548.0), 'waypoint_segment': 'VMR-LENDA', 'vertical_state': 'descent', 'time_in_cell': np.float64(3020.0)}, {'flight_id': 'SQ11_B738_trajectory', 'timestamp': np.int64(590), 'altitude': np.float64(38185.0), 'waypoint_segment': 'VMR-LENDA', 'vertical_state': 'descent', 'time_in_cell': np.float64(3010.0)}, {'flight_id': 'SQ11_B738_trajectory', 'timestamp': np.int64(600), 'altitude': np.float64(37822.0), 'waypoint_segment': 'VMR-LENDA', 'vertical_state': 'descent', 'time_in_cell': np.float64(3000.0)}, {'flight_id': 'SQ11_B738_trajectory', 'timestamp': np.int64(610), 'altitude': np.float64(37459.0), 'waypoint_segment': 'VMR-LENDA', 'vertical_state': 'descent', 'time_in_cell': np.float64(2990.0)}])

# %%
c.cells[np.int64(3), np.int64(0), np.int64(7), np.int64(0)].aircraft_records
# Out:
# [{'flight_id': 'SQ10_B738_trajectory',
#   'timestamp': np.int64(300),
#   'altitude': np.float64(39637.0),
#   'waypoint_segment': 'VMR-LENDA',
#   'vertical_state': 'descent',
#   'time_in_cell': np.float64(3300.0)},
#  {'flight_id': 'SQ10_B738_trajectory',
#   'timestamp': np.int64(310),
#   'altitude': np.float64(39274.0),
#   'waypoint_segment': 'VMR-LENDA',
#   'vertical_state': 'descent',
#   'time_in_cell': np.float64(3290.0)},
#  {'flight_id': 'SQ10_B738_trajectory',
#   'timestamp': np.int64(320),
#   'altitude': np.float64(38911.0),
#   'waypoint_segment': 'VMR-LENDA',
#   'vertical_state': 'descent',
#   'time_in_cell': np.float64(3280.0)},
#  {'flight_id': 'SQ10_B738_trajectory',
#   'timestamp': np.int64(330),
#   'altitude': np.float64(38548.0),
#   'waypoint_segment': 'VMR-LENDA',
#   'vertical_state': 'descent',
#   'time_in_cell': np.float64(3270.0)},
#  {'flight_id': 'SQ10_B738_trajectory',
#   'timestamp': np.int64(340),
#   'altitude': np.float64(38185.0),
#   'waypoint_segment': 'VMR-LENDA',
#   'vertical_state': 'descent',
#   'time_in_cell': np.float64(3260.0)},
#  {'flight_id': 'SQ10_B738_trajectory',
#   'timestamp': np.int64(350),
#   'altitude': np.float64(37822.0),
#   'waypoint_segment': 'VMR-LENDA',
#   'vertical_state': 'descent',
#   'time_in_cell': np.float64(3250.0)},
#  {'flight_id': 'SQ10_B738_trajectory',
#   'timestamp': np.int64(360),
#   'altitude': np.float64(37459.0),
#   'waypoint_segment': 'VMR-LENDA',
#   'vertical_state': 'descent',
#   'time_in_cell': np.float64(3240.0)},
#  {'flight_id': 'SQ11_B738_trajectory',
#   'timestamp': np.int64(550),
#   'altitude': np.float64(39637.0),
#   'waypoint_segment': 'VMR-LENDA',
#   'vertical_state': 'descent',
#   'time_in_cell': np.float64(3050.0)},
#  {'flight_id': 'SQ11_B738_trajectory',
#   'timestamp': np.int64(560),
#   'altitude': np.float64(39274.0),
#   'waypoint_segment': 'VMR-LENDA',
#   'vertical_state': 'descent',
#   'time_in_cell': np.float64(3040.0)},
#  {'flight_id': 'SQ11_B738_trajectory',
#   'timestamp': np.int64(570),
#   'altitude': np.float64(38911.0),
#   'waypoint_segment': 'VMR-LENDA',
#   'vertical_state': 'descent',
#   'time_in_cell': np.float64(3030.0)},
#  {'flight_id': 'SQ11_B738_trajectory',
#   'timestamp': np.int64(580),
#   'altitude': np.float64(38548.0),
#   'waypoint_segment': 'VMR-LENDA',
#   'vertical_state': 'descent',
#   'time_in_cell': np.float64(3020.0)},
#  {'flight_id': 'SQ11_B738_trajectory',
#   'timestamp': np.int64(590),
#   'altitude': np.float64(38185.0),
#   'waypoint_segment': 'VMR-LENDA',
#   'vertical_state': 'descent',
#   'time_in_cell': np.float64(3010.0)},
#  {'flight_id': 'SQ11_B738_trajectory',
#   'timestamp': np.int64(600),
#   'altitude': np.float64(37822.0),
#   'waypoint_segment': 'VMR-LENDA',
#   'vertical_state': 'descent',
#   'time_in_cell': np.float64(3000.0)},
#  {'flight_id': 'SQ11_B738_trajectory',
#   'timestamp': np.int64(610),
#   'altitude': np.float64(37459.0),
#   'waypoint_segment': 'VMR-LENDA',
#   'vertical_state': 'descent',
#   'time_in_cell': np.float64(2990.0)}]

# %%
for k, v in c.cells.items():
    print(f"key: {k}, Value: {v}")
# Out:
# key: (np.int64(3), np.int64(0), np.int64(7), np.int64(0)), Value: Cell4D(x_min=np.float64(103.67194399999998), x_max=np.float64(104.00527733333331), y_min=np.float64(2.161111), y_max=np.float64(2.4944443333333335), z_min=np.float64(37333.330000000016), z_max=np.float64(40333.330000000016), t_min=np.float64(0.0), t_max=np.float64(3600.0), aircraft_records=[{'flight_id': 'SQ10_B738_trajectory', 'timestamp': np.int64(300), 'altitude': np.float64(39637.0), 'waypoint_segment': 'VMR-LENDA', 'vertical_state': 'descent', 'time_in_cell': np.float64(3300.0)}, {'flight_id': 'SQ10_B738_trajectory', 'timestamp': np.int64(310), 'altitude': np.float64(39274.0), 'waypoint_segment': 'VMR-LENDA', 'vertical_state': 'descent', 'time_in_cell': np.float64(3290.0)}, {'flight_id': 'SQ10_B738_trajectory', 'timestamp': np.int64(320), 'altitude': np.float64(38911.0), 'waypoint_segment': 'VMR-LENDA', 'vertical_state': 'descent', 'time_in_cell': np.float64(3280.0)}, {'flight_id': 'SQ10_B738_trajectory', 'timestamp': np.int64(330), 'altitude': np.float64(38548.0), 'waypoint_segment': 'VMR-LENDA', 'vertical_state': 'descent', 'time_in_cell': np.float64(3270.0)}, {'flight_id': 'SQ10_B738_trajectory', 'timestamp': np.int64(340), 'altitude': np.float64(38185.0), 'waypoint_segment': 'VMR-LENDA', 'vertical_state': 'descent', 'time_in_cell': np.float64(3260.0)}, {'flight_id': 'SQ10_B738_trajectory', 'timestamp': np.int64(350), 'altitude': np.float64(37822.0), 'waypoint_segment': 'VMR-LENDA', 'vertical_state': 'descent', 'time_in_cell': np.float64(3250.0)}, {'flight_id': 'SQ10_B738_trajectory', 'timestamp': np.int64(360), 'altitude': np.float64(37459.0), 'waypoint_segment': 'VMR-LENDA', 'vertical_state': 'descent', 'time_in_cell': np.float64(3240.0)}, {'flight_id': 'SQ11_B738_trajectory', 'timestamp': np.int64(550), 'altitude': np.float64(39637.0), 'waypoint_segment': 'VMR-LENDA', 'vertical_state': 'descent', 'time_in_cell': np.float64(3050.0)}, {'flight_id': 'SQ11_B738_trajectory', 'timestamp': np.int64(560), 'altitude': np.float64(39274.0), 'waypoint_segment': 'VMR-LENDA', 'vertical_state': 'descent', 'time_in_cell': np.float64(3040.0)}, {'flight_id': 'SQ11_B738_trajectory', 'timestamp': np.int64(570), 'altitude': np.float64(38911.0), 'waypoint_segment': 'VMR-LENDA', 'vertical_state': 'descent', 'time_in_cell': np.float64(3030.0)}, {'flight_id': 'SQ11_B738_trajectory', 'timestamp': np.int64(580), 'altitude': np.float64(38548.0), 'waypoint_segment': 'VMR-LENDA', 'vertical_state': 'descent', 'time_in_cell': np.float64(3020.0)}, {'flight_id': 'SQ11_B738_trajectory', 'timestamp': np.int64(590), 'altitude': np.float64(38185.0), 'waypoint_segment': 'VMR-LENDA', 'vertical_state': 'descent', 'time_in_cell': np.float64(3010.0)}, {'flight_id': 'SQ11_B738_trajectory', 'timestamp': np.int64(600), 'altitude': np.float64(37822.0), 'waypoint_segment': 'VMR-LENDA', 'vertical_state': 'descent', 'time_in_cell': np.float64(3000.0)}, {'flight_id': 'SQ11_B738_trajectory', 'timestamp': np.int64(610), 'altitude': np.float64(37459.0), 'waypoint_segment': 'VMR-LENDA', 'vertical_state': 'descent', 'time_in_cell': np.float64(2990.0)}])
# key: (np.int64(3), np.int64(0), np.int64(6), np.int64(0)), Value: Cell4D(x_min=np.float64(103.67194399999998), x_max=np.float64(104.00527733333331), y_min=np.float64(2.161111), y_max=np.float64(2.4944443333333335), z_min=np.float64(34333.33000000001), z_max=np.float64(37333.330000000016), t_min=np.float64(0.0), t_max=np.float64(3600.0), aircraft_records=[{'flight_id': 'SQ10_B738_trajectory', 'timestamp': np.int64(370), 'altitude': np.float64(37096.0), 'waypoint_segment': 'VMR-LENDA', 'vertical_state': 'descent', 'time_in_cell': np.float64(3230.0)}, {'flight_id': 'SQ10_B738_trajectory', 'timestamp': np.int64(380), 'altitude': np.float64(36733.0), 'waypoint_segment': 'VMR-LENDA', 'vertical_state': 'descent', 'time_in_cell': np.float64(3220.0)}, {'flight_id': 'SQ11_B738_trajectory', 'timestamp': np.int64(620), 'altitude': np.float64(37096.0), 'waypoint_segment': 'VMR-LENDA', 'vertical_state': 'descent', 'time_in_cell': np.float64(2980.0)}, {'flight_id': 'SQ11_B738_trajectory', 'timestamp': np.int64(630), 'altitude': np.float64(36733.0), 'waypoint_segment': 'VMR-LENDA', 'vertical_state': 'descent', 'time_in_cell': np.float64(2970.0)}])
# key: (np.int64(4), np.int64(0), np.int64(6), np.int64(0)), Value: Cell4D(x_min=np.float64(104.00527733333331), x_max=np.float64(104.33861066666664), y_min=np.float64(2.161111), y_max=np.float64(2.4944443333333335), z_min=np.float64(34333.33000000001), z_max=np.float64(37333.330000000016), t_min=np.float64(0.0), t_max=np.float64(3600.0), aircraft_records=[{'flight_id': 'SQ10_B738_trajectory', 'timestamp': np.int64(390), 'altitude': np.float64(36370.0), 'waypoint_segment': 'VMR-LENDA', 'vertical_state': 'descent', 'time_in_cell': np.float64(3210.0)}, {'flight_id': 'SQ10_B738_trajectory', 'timestamp': np.int64(400), 'altitude': np.float64(36007.0), 'waypoint_segment': 'VMR-LENDA', 'vertical_state': 'descent', 'time_in_cell': np.float64(3200.0)}, {'flight_id': 'SQ10_B738_trajectory', 'timestamp': np.int64(410), 'altitude': np.float64(35644.0), 'waypoint_segment': 'VMR-LENDA', 'vertical_state': 'descent', 'time_in_cell': np.float64(3190.0)}, {'flight_id': 'SQ10_B738_trajectory', 'timestamp': np.int64(420), 'altitude': np.float64(35281.0), 'waypoint_segment': 'VMR-LENDA', 'vertical_state': 'descent', 'time_in_cell': np.float64(3180.0)}, {'flight_id': 'SQ10_B738_trajectory', 'timestamp': np.int64(430), 'altitude': np.float64(35000.0), 'waypoint_segment': 'VMR-LENDA', 'vertical_state': 'cruise', 'time_in_cell': np.float64(3170.0)}, {'flight_id': 'SQ10_B738_trajectory', 'timestamp': np.int64(440), 'altitude': np.float64(35000.0), 'waypoint_segment': 'VMR-LENDA', 'vertical_state': 'cruise', 'time_in_cell': np.float64(3160.0)}, {'flight_id': 'SQ10_B738_trajectory', 'timestamp': np.int64(450), 'altitude': np.float64(35000.0), 'waypoint_segment': 'VMR-LENDA', 'vertical_state': 'cruise', 'time_in_cell': np.float64(3150.0)}, {'flight_id': 'SQ10_B738_trajectory', 'timestamp': np.int64(460), 'altitude': np.float64(35000.0), 'waypoint_segment': 'VMR-LENDA', 'vertical_state': 'cruise', 'time_in_cell': np.float64(3140.0)}, {'flight_id': 'SQ10_B738_trajectory', 'timestamp': np.int64(470), 'altitude': np.float64(35000.0), 'waypoint_segment': 'VMR-LENDA', 'vertical_state': 'cruise', 'time_in_cell': np.float64(3130.0)}, {'flight_id': 'SQ11_B738_trajectory', 'timestamp': np.int64(640), 'altitude': np.float64(36370.0), 'waypoint_segment': 'VMR-LENDA', 'vertical_state': 'descent', 'time_in_cell': np.float64(2960.0)}, {'flight_id': 'SQ11_B738_trajectory', 'timestamp': np.int64(650), 'altitude': np.float64(36007.0), 'waypoint_segment': 'VMR-LENDA', 'vertical_state': 'descent', 'time_in_cell': np.float64(2950.0)}, {'flight_id': 'SQ11_B738_trajectory', 'timestamp': np.int64(660), 'altitude': np.float64(35644.0), 'waypoint_segment': 'VMR-LENDA', 'vertical_state': 'descent', 'time_in_cell': np.float64(2940.0)}, {'flight_id': 'SQ11_B738_trajectory', 'timestamp': np.int64(670), 'altitude': np.float64(35281.0), 'waypoint_segment': 'VMR-LENDA', 'vertical_state': 'descent', 'time_in_cell': np.float64(2930.0)}, {'flight_id': 'SQ11_B738_trajectory', 'timestamp': np.int64(680), 'altitude': np.float64(35000.0), 'waypoint_segment': 'VMR-LENDA', 'vertical_state': 'cruise', 'time_in_cell': np.float64(2920.0)}, {'flight_id': 'SQ11_B738_trajectory', 'timestamp': np.int64(690), 'altitude': np.float64(35000.0), 'waypoint_segment': 'VMR-LENDA', 'vertical_state': 'cruise', 'time_in_cell': np.float64(2910.0)}, {'flight_id': 'SQ11_B738_trajectory', 'timestamp': np.int64(700), 'altitude': np.float64(35000.0), 'waypoint_segment': 'VMR-LENDA', 'vertical_state': 'cruise', 'time_in_cell': np.float64(2900.0)}, {'flight_id': 'SQ11_B738_trajectory', 'timestamp': np.int64(710), 'altitude': np.float64(35000.0), 'waypoint_segment': 'VMR-LENDA', 'vertical_state': 'cruise', 'time_in_cell': np.float64(2890.0)}, {'flight_id': 'SQ11_B738_trajectory', 'timestamp': np.int64(720), 'altitude': np.float64(35000.0), 'waypoint_segment': 'VMR-LENDA', 'vertical_state': 'cruise', 'time_in_cell': np.float64(2880.0)}])
# key: (np.int64(4), np.int64(1), np.int64(6), np.int64(0)), Value: Cell4D(x_min=np.float64(104.00527733333331), x_max=np.float64(104.33861066666664), y_min=np.float64(2.4944443333333335), y_max=np.float64(2.827777666666667), z_min=np.float64(34333.33000000001), z_max=np.float64(37333.330000000016), t_min=np.float64(0.0), t_max=np.float64(3600.0), aircraft_records=[{'flight_id': 'SQ10_B738_trajectory', 'timestamp': np.int64(480), 'altitude': np.float64(35000.0), 'waypoint_segment': 'VMR-LENDA', 'vertical_state': 'cruise', 'time_in_cell': np.float64(3120.0)}, {'flight_id': 'SQ10_B738_trajectory', 'timestamp': np.int64(490), 'altitude': np.float64(35000.0), 'waypoint_segment': 'VMR-LENDA', 'vertical_state': 'cruise', 'time_in_cell': np.float64(3110.0)}, {'flight_id': 'SQ10_B738_trajectory', 'timestamp': np.int64(500), 'altitude': np.float64(35000.0), 'waypoint_segment': 'VMR-LENDA', 'vertical_state': 'cruise', 'time_in_cell': np.float64(3100.0)}, {'flight_id': 'SQ10_B738_trajectory', 'timestamp': np.int64(510), 'altitude': np.float64(35000.0), 'waypoint_segment': 'VMR-LENDA', 'vertical_state': 'cruise', 'time_in_cell': np.float64(3090.0)}, {'flight_id': 'SQ10_B738_trajectory', 'timestamp': np.int64(520), 'altitude': np.float64(35000.0), 'waypoint_segment': 'VMR-LENDA', 'vertical_state': 'cruise', 'time_in_cell': np.float64(3080.0)}, {'flight_id': 'SQ10_B738_trajectory', 'timestamp': np.int64(530), 'altitude': np.float64(35000.0), 'waypoint_segment': 'VMR-LENDA', 'vertical_state': 'cruise', 'time_in_cell': np.float64(3070.0)}, {'flight_id': 'SQ10_B738_trajectory', 'timestamp': np.int64(540), 'altitude': np.float64(35000.0), 'waypoint_segment': 'VMR-LENDA', 'vertical_state': 'cruise', 'time_in_cell': np.float64(3060.0)}, {'flight_id': 'SQ10_B738_trajectory', 'timestamp': np.int64(550), 'altitude': np.float64(35000.0), 'waypoint_segment': 'VMR-LENDA', 'vertical_state': 'cruise', 'time_in_cell': np.float64(3050.0)}, {'flight_id': 'SQ10_B738_trajectory', 'timestamp': np.int64(560), 'altitude': np.float64(35000.0), 'waypoint_segment': 'VMR-LENDA', 'vertical_state': 'cruise', 'time_in_cell': np.float64(3040.0)}, {'flight_id': 'SQ10_B738_trajectory', 'timestamp': np.int64(570), 'altitude': np.float64(35000.0), 'waypoint_segment': 'VMR-LENDA', 'vertical_state': 'cruise', 'time_in_cell': np.float64(3030.0)}, {'flight_id': 'SQ10_B738_trajectory', 'timestamp': np.int64(580), 'altitude': np.float64(35000.0), 'waypoint_segment': 'VMR-LENDA', 'vertical_state': 'cruise', 'time_in_cell': np.float64(3020.0)}, {'flight_id': 'SQ10_B738_trajectory', 'timestamp': np.int64(590), 'altitude': np.float64(35000.0), 'waypoint_segment': 'VMR-LENDA', 'vertical_state': 'cruise', 'time_in_cell': np.float64(3010.0)}, {'flight_id': 'SQ10_B738_trajectory', 'timestamp': np.int64(600), 'altitude': np.float64(35000.0), 'waypoint_segment': 'VMR-LENDA', 'vertical_state': 'cruise', 'time_in_cell': np.float64(3000.0)}, {'flight_id': 'SQ11_B738_trajectory', 'timestamp': np.int64(730), 'altitude': np.float64(35000.0), 'waypoint_segment': 'VMR-LENDA', 'vertical_state': 'cruise', 'time_in_cell': np.float64(2870.0)}, {'flight_id': 'SQ11_B738_trajectory', 'timestamp': np.int64(740), 'altitude': np.float64(35000.0), 'waypoint_segment': 'VMR-LENDA', 'vertical_state': 'cruise', 'time_in_cell': np.float64(2860.0)}, {'flight_id': 'SQ11_B738_trajectory', 'timestamp': np.int64(750), 'altitude': np.float64(35000.0), 'waypoint_segment': 'VMR-LENDA', 'vertical_state': 'cruise', 'time_in_cell': np.float64(2850.0)}, {'flight_id': 'SQ11_B738_trajectory', 'timestamp': np.int64(760), 'altitude': np.float64(35000.0), 'waypoint_segment': 'VMR-LENDA', 'vertical_state': 'cruise', 'time_in_cell': np.float64(2840.0)}, {'flight_id': 'SQ11_B738_trajectory', 'timestamp': np.int64(770), 'altitude': np.float64(35000.0), 'waypoint_segment': 'VMR-LENDA', 'vertical_state': 'cruise', 'time_in_cell': np.float64(2830.0)}, {'flight_id': 'SQ11_B738_trajectory', 'timestamp': np.int64(780), 'altitude': np.float64 ...
# key: (np.int64(5), np.int64(1), np.int64(6), np.int64(0)), Value: Cell4D(x_min=np.float64(104.33861066666664), x_max=np.float64(104.67194399999997), y_min=np.float64(2.4944443333333335), y_max=np.float64(2.827777666666667), z_min=np.float64(34333.33000000001), z_max=np.float64(37333.330000000016), t_min=np.float64(0.0), t_max=np.float64(3600.0), aircraft_records=[{'flight_id': 'SQ10_B738_trajectory', 'timestamp': np.int64(610), 'altitude': np.float64(35000.0), 'waypoint_segment': 'VMR-LENDA', 'vertical_state': 'cruise', 'time_in_cell': np.float64(2990.0)}, {'flight_id': 'SQ10_B738_trajectory', 'timestamp': np.int64(620), 'altitude': np.float64(35000.0), 'waypoint_segment': 'VMR-LENDA', 'vertical_state': 'cruise', 'time_in_cell': np.float64(2980.0)}, {'flight_id': 'SQ10_B738_trajectory', 'timestamp': np.int64(630), 'altitude': np.float64(35000.0), 'waypoint_segment': 'VMR-LENDA', 'vertical_state': 'cruise', 'time_in_cell': np.float64(2970.0)}, {'flight_id': 'SQ10_B738_trajectory', 'timestamp': np.int64(640), 'altitude': np.float64(35000.0), 'waypoint_segment': 'VMR-LENDA', 'vertical_state': 'cruise', 'time_in_cell': np.float64(2960.0)}, {'flight_id': 'SQ10_B738_trajectory', 'timestamp': np.int64(650), 'altitude': np.float64(35000.0), 'waypoint_segment': 'VMR-LENDA', 'vertical_state': 'cruise', 'time_in_cell': np.float64(2950.0)}, {'flight_id': 'SQ10_B738_trajectory', 'timestamp': np.int64(660), 'altitude': np.float64(35000.0), 'waypoint_segment': 'VMR-LENDA', 'vertical_state': 'cruise', 'time_in_cell': np.float64(2940.0)}, {'flight_id': 'SQ10_B738_trajectory', 'timestamp': np.int64(670), 'altitude': np.float64(35000.0), 'waypoint_segment': 'VMR-LENDA', 'vertical_state': 'cruise', 'time_in_cell': np.float64(2930.0)}, {'flight_id': 'SQ10_B738_trajectory', 'timestamp': np.int64(680), 'altitude': np.float64(35000.0), 'waypoint_segment': 'VMR-LENDA', 'vertical_state': 'cruise', 'time_in_cell': np.float64(2920.0)}, {'flight_id': 'SQ10_B738_trajectory', 'timestamp': np.int64(690), 'altitude': np.float64(35000.0), 'waypoint_segment': 'VMR-LENDA', 'vertical_state': 'cruise', 'time_in_cell': np.float64(2910.0)}, {'flight_id': 'SQ10_B738_trajectory', 'timestamp': np.int64(700), 'altitude': np.float64(35000.0), 'waypoint_segment': 'VMR-LENDA', 'vertical_state': 'cruise', 'time_in_cell': np.float64(2900.0)}, {'flight_id': 'SQ10_B738_trajectory', 'timestamp': np.int64(710), 'altitude': np.float64(35000.0), 'waypoint_segment': 'VMR-LENDA', 'vertical_state': 'cruise', 'time_in_cell': np.float64(2890.0)}, {'flight_id': 'SQ10_B738_trajectory', 'timestamp': np.int64(720), 'altitude': np.float64(35000.0), 'waypoint_segment': 'VMR-LENDA', 'vertical_state': 'cruise', 'time_in_cell': np.float64(2880.0)}, {'flight_id': 'SQ10_B738_trajectory', 'timestamp': np.int64(730), 'altitude': np.float64(35000.0), 'waypoint_segment': 'VMR-LENDA', 'vertical_state': 'cruise', 'time_in_cell': np.float64(2870.0)}, {'flight_id': 'SQ10_B738_trajectory', 'timestamp': np.int64(740), 'altitude': np.float64(35000.0), 'waypoint_segment': 'VMR-LENDA', 'vertical_state': 'cruise', 'time_in_cell': np.float64(2860.0)}, {'flight_id': 'SQ10_B738_trajectory', 'timestamp': np.int64(750), 'altitude': np.float64(35000.0), 'waypoint_segment': 'VMR-LENDA', 'vertical_state': 'cruise', 'time_in_cell': np.float64(2850.0)}, {'flight_id': 'SQ10_B738_trajectory', 'timestamp': np.int64(760), 'altitude': np.float64(35000.0), 'waypoint_segment': 'VMR-LENDA', 'vertical_state': 'cruise', 'time_in_cell': np.float64(2840.0)}, {'flight_id': 'SQ10_B738_trajectory', 'timestamp': np.int64(770), 'altitude': np.float64(35000.0), 'waypoint_segment': 'VMR-LENDA', 'vertical_state': 'cruise', 'time_in_cell': np.float64(2830.0)}, {'flight_id': 'SQ10_B738_trajectory', 'timestamp': np.int64(780), 'altitude': np.float64(35000.0), 'waypoint_segment': 'VMR-LENDA', 'vertical_state': 'cruise', 'time_in_cell': np.float64(2820.0)}, {'flight_id': 'SQ10_B738_trajectory', 'timestamp': np.int64(790), 'altitude': np.float64 ...
# key: (np.int64(6), np.int64(1), np.int64(6), np.int64(0)), Value: Cell4D(x_min=np.float64(104.67194399999997), x_max=np.float64(105.0052773333333), y_min=np.float64(2.4944443333333335), y_max=np.float64(2.827777666666667), z_min=np.float64(34333.33000000001), z_max=np.float64(37333.330000000016), t_min=np.float64(0.0), t_max=np.float64(3600.0), aircraft_records=[{'flight_id': 'SQ10_B738_trajectory', 'timestamp': np.int64(840), 'altitude': np.float64(35000.0), 'waypoint_segment': 'LENDA-LIPRO', 'vertical_state': 'cruise', 'time_in_cell': np.float64(2760.0)}, {'flight_id': 'SQ10_B738_trajectory', 'timestamp': np.int64(850), 'altitude': np.float64(35000.0), 'waypoint_segment': 'LENDA-LIPRO', 'vertical_state': 'cruise', 'time_in_cell': np.float64(2750.0)}, {'flight_id': 'SQ10_B738_trajectory', 'timestamp': np.int64(860), 'altitude': np.float64(35000.0), 'waypoint_segment': 'LENDA-LIPRO', 'vertical_state': 'cruise', 'time_in_cell': np.float64(2740.0)}, {'flight_id': 'SQ10_B738_trajectory', 'timestamp': np.int64(870), 'altitude': np.float64(35000.0), 'waypoint_segment': 'LENDA-LIPRO', 'vertical_state': 'cruise', 'time_in_cell': np.float64(2730.0)}, {'flight_id': 'SQ10_B738_trajectory', 'timestamp': np.int64(880), 'altitude': np.float64(35000.0), 'waypoint_segment': 'LENDA-LIPRO', 'vertical_state': 'cruise', 'time_in_cell': np.float64(2720.0)}, {'flight_id': 'SQ10_B738_trajectory', 'timestamp': np.int64(890), 'altitude': np.float64(35000.0), 'waypoint_segment': 'LENDA-LIPRO', 'vertical_state': 'cruise', 'time_in_cell': np.float64(2710.0)}, {'flight_id': 'SQ10_B738_trajectory', 'timestamp': np.int64(900), 'altitude': np.float64(35000.0), 'waypoint_segment': 'LENDA-LIPRO', 'vertical_state': 'cruise', 'time_in_cell': np.float64(2700.0)}, {'flight_id': 'SQ10_B738_trajectory', 'timestamp': np.int64(910), 'altitude': np.float64(35000.0), 'waypoint_segment': 'LENDA-LIPRO', 'vertical_state': 'cruise', 'time_in_cell': np.float64(2690.0)}, {'flight_id': 'SQ10_B738_trajectory', 'timestamp': np.int64(920), 'altitude': np.float64(35000.0), 'waypoint_segment': 'LENDA-LIPRO', 'vertical_state': 'cruise', 'time_in_cell': np.float64(2680.0)}, {'flight_id': 'SQ10_B738_trajectory', 'timestamp': np.int64(930), 'altitude': np.float64(35000.0), 'waypoint_segment': 'LENDA-LIPRO', 'vertical_state': 'cruise', 'time_in_cell': np.float64(2670.0)}, {'flight_id': 'SQ10_B738_trajectory', 'timestamp': np.int64(940), 'altitude': np.float64(35000.0), 'waypoint_segment': 'LENDA-LIPRO', 'vertical_state': 'cruise', 'time_in_cell': np.float64(2660.0)}, {'flight_id': 'SQ10_B738_trajectory', 'timestamp': np.int64(950), 'altitude': np.float64(35000.0), 'waypoint_segment': 'LENDA-LIPRO', 'vertical_state': 'cruise', 'time_in_cell': np.float64(2650.0)}, {'flight_id': 'SQ10_B738_trajectory', 'timestamp': np.int64(960), 'altitude': np.float64(35000.0), 'waypoint_segment': 'LENDA-LIPRO', 'vertical_state': 'cruise', 'time_in_cell': np.float64(2640.0)}, {'flight_id': 'SQ10_B738_trajectory', 'timestamp': np.int64(970), 'altitude': np.float64(35000.0), 'waypoint_segment': 'LENDA-LIPRO', 'vertical_state': 'cruise', 'time_in_cell': np.float64(2630.0)}, {'flight_id': 'SQ10_B738_trajectory', 'timestamp': np.int64(980), 'altitude': np.float64(35000.0), 'waypoint_segment': 'LENDA-LIPRO', 'vertical_state': 'cruise', 'time_in_cell': np.float64(2620.0)}, {'flight_id': 'SQ10_B738_trajectory', 'timestamp': np.int64(990), 'altitude': np.float64(35000.0), 'waypoint_segment': 'LENDA-LIPRO', 'vertical_state': 'cruise', 'time_in_cell': np.float64(2610.0)}, {'flight_id': 'SQ10_B738_trajectory', 'timestamp': np.int64(1000), 'altitude': np.float64(35000.0), 'waypoint_segment': 'LENDA-LIPRO', 'vertical_state': 'cruise', 'time_in_cell': np.float64(2600.0)}, {'flight_id': 'SQ10_B738_trajectory', 'timestamp': np.int64(1010), 'altitude': np.float64(35000.0), 'waypoint_segment': 'LENDA-LIPRO', 'vertical_state': 'cruise', 'time_in_cell': np.float64(2590.0)}, {'flight_id': 'SQ10_B738_trajectory', 'timestamp':  ...
# key: (np.int64(7), np.int64(1), np.int64(6), np.int64(0)), Value: Cell4D(x_min=np.float64(105.0052773333333), x_max=np.float64(105.33861066666663), y_min=np.float64(2.4944443333333335), y_max=np.float64(2.827777666666667), z_min=np.float64(34333.33000000001), z_max=np.float64(37333.330000000016), t_min=np.float64(0.0), t_max=np.float64(3600.0), aircraft_records=[{'flight_id': 'SQ10_B738_trajectory', 'timestamp': np.int64(1060), 'altitude': np.float64(35000.0), 'waypoint_segment': 'LENDA-LIPRO', 'vertical_state': 'cruise', 'time_in_cell': np.float64(2540.0)}, {'flight_id': 'SQ11_B738_trajectory', 'timestamp': np.int64(1310), 'altitude': np.float64(35000.0), 'waypoint_segment': 'LENDA-LIPRO', 'vertical_state': 'cruise', 'time_in_cell': np.float64(2290.0)}])
# key: (np.int64(7), np.int64(2), np.int64(6), np.int64(0)), Value: Cell4D(x_min=np.float64(105.0052773333333), x_max=np.float64(105.33861066666663), y_min=np.float64(2.827777666666667), y_max=np.float64(3.1611110000000004), z_min=np.float64(34333.33000000001), z_max=np.float64(37333.330000000016), t_min=np.float64(0.0), t_max=np.float64(3600.0), aircraft_records=[{'flight_id': 'SQ10_B738_trajectory', 'timestamp': np.int64(1070), 'altitude': np.float64(35000.0), 'waypoint_segment': 'LENDA-LIPRO', 'vertical_state': 'cruise', 'time_in_cell': np.float64(2530.0)}, {'flight_id': 'SQ10_B738_trajectory', 'timestamp': np.int64(1080), 'altitude': np.float64(35000.0), 'waypoint_segment': 'LENDA-LIPRO', 'vertical_state': 'cruise', 'time_in_cell': np.float64(2520.0)}, {'flight_id': 'SQ10_B738_trajectory', 'timestamp': np.int64(1090), 'altitude': np.float64(35000.0), 'waypoint_segment': 'LENDA-LIPRO', 'vertical_state': 'cruise', 'time_in_cell': np.float64(2510.0)}, {'flight_id': 'SQ10_B738_trajectory', 'timestamp': np.int64(1100), 'altitude': np.float64(35000.0), 'waypoint_segment': 'LENDA-LIPRO', 'vertical_state': 'cruise', 'time_in_cell': np.float64(2500.0)}, {'flight_id': 'SQ10_B738_trajectory', 'timestamp': np.int64(1110), 'altitude': np.float64(35000.0), 'waypoint_segment': 'LENDA-LIPRO', 'vertical_state': 'cruise', 'time_in_cell': np.float64(2490.0)}, {'flight_id': 'SQ10_B738_trajectory', 'timestamp': np.int64(1120), 'altitude': np.float64(35000.0), 'waypoint_segment': 'LENDA-LIPRO', 'vertical_state': 'cruise', 'time_in_cell': np.float64(2480.0)}, {'flight_id': 'SQ10_B738_trajectory', 'timestamp': np.int64(1130), 'altitude': np.float64(35000.0), 'waypoint_segment': 'LENDA-LIPRO', 'vertical_state': 'cruise', 'time_in_cell': np.float64(2470.0)}, {'flight_id': 'SQ10_B738_trajectory', 'timestamp': np.int64(1140), 'altitude': np.float64(35000.0), 'waypoint_segment': 'LENDA-LIPRO', 'vertical_state': 'cruise', 'time_in_cell': np.float64(2460.0)}, {'flight_id': 'SQ10_B738_trajectory', 'timestamp': np.int64(1150), 'altitude': np.float64(35000.0), 'waypoint_segment': 'LENDA-LIPRO', 'vertical_state': 'cruise', 'time_in_cell': np.float64(2450.0)}, {'flight_id': 'SQ10_B738_trajectory', 'timestamp': np.int64(1160), 'altitude': np.float64(35000.0), 'waypoint_segment': 'LENDA-LIPRO', 'vertical_state': 'cruise', 'time_in_cell': np.float64(2440.0)}, {'flight_id': 'SQ10_B738_trajectory', 'timestamp': np.int64(1170), 'altitude': np.float64(35000.0), 'waypoint_segment': 'LENDA-LIPRO', 'vertical_state': 'cruise', 'time_in_cell': np.float64(2430.0)}, {'flight_id': 'SQ10_B738_trajectory', 'timestamp': np.int64(1180), 'altitude': np.float64(35000.0), 'waypoint_segment': 'LIPRO-LEBIN', 'vertical_state': 'cruise', 'time_in_cell': np.float64(2420.0)}, {'flight_id': 'SQ10_B738_trajectory', 'timestamp': np.int64(1190), 'altitude': np.float64(35000.0), 'waypoint_segment': 'LIPRO-LEBIN', 'vertical_state': 'cruise', 'time_in_cell': np.float64(2410.0)}, {'flight_id': 'SQ10_B738_trajectory', 'timestamp': np.int64(1200), 'altitude': np.float64(35000.0), 'waypoint_segment': 'LIPRO-LEBIN', 'vertical_state': 'cruise', 'time_in_cell': np.float64(2400.0)}, {'flight_id': 'SQ10_B738_trajectory', 'timestamp': np.int64(1210), 'altitude': np.float64(35000.0), 'waypoint_segment': 'LIPRO-LEBIN', 'vertical_state': 'cruise', 'time_in_cell': np.float64(2390.0)}, {'flight_id': 'SQ10_B738_trajectory', 'timestamp': np.int64(1220), 'altitude': np.float64(35000.0), 'waypoint_segment': 'LIPRO-LEBIN', 'vertical_state': 'cruise', 'time_in_cell': np.float64(2380.0)}, {'flight_id': 'SQ10_B738_trajectory', 'timestamp': np.int64(1230), 'altitude': np.float64(35000.0), 'waypoint_segment': 'LIPRO-LEBIN', 'vertical_state': 'cruise', 'time_in_cell': np.float64(2370.0)}, {'flight_id': 'SQ10_B738_trajectory', 'timestamp': np.int64(1240), 'altitude': np.float64(35000.0), 'waypoint_segment': 'LIPRO-LEBIN', 'vertical_state': 'cruise', 'time_in_cell': np.float64(2360.0)}, {'flight_id': 'SQ10_B738_trajectory ...
# key: (np.int64(8), np.int64(2), np.int64(6), np.int64(0)), Value: Cell4D(x_min=np.float64(105.33861066666663), x_max=np.float64(105.67194399999995), y_min=np.float64(2.827777666666667), y_max=np.float64(3.1611110000000004), z_min=np.float64(34333.33000000001), z_max=np.float64(37333.330000000016), t_min=np.float64(0.0), t_max=np.float64(3600.0), aircraft_records=[{'flight_id': 'SQ10_B738_trajectory', 'timestamp': np.int64(1280), 'altitude': np.float64(35000.0), 'waypoint_segment': 'LIPRO-LEBIN', 'vertical_state': 'cruise', 'time_in_cell': np.float64(2320.0)}, {'flight_id': 'SQ10_B738_trajectory', 'timestamp': np.int64(1290), 'altitude': np.float64(35000.0), 'waypoint_segment': 'LIPRO-LEBIN', 'vertical_state': 'cruise', 'time_in_cell': np.float64(2310.0)}, {'flight_id': 'SQ10_B738_trajectory', 'timestamp': np.int64(1300), 'altitude': np.float64(35000.0), 'waypoint_segment': 'LIPRO-LEBIN', 'vertical_state': 'cruise', 'time_in_cell': np.float64(2300.0)}, {'flight_id': 'SQ10_B738_trajectory', 'timestamp': np.int64(1310), 'altitude': np.float64(35000.0), 'waypoint_segment': 'LIPRO-LEBIN', 'vertical_state': 'cruise', 'time_in_cell': np.float64(2290.0)}, {'flight_id': 'SQ10_B738_trajectory', 'timestamp': np.int64(1320), 'altitude': np.float64(35000.0), 'waypoint_segment': 'LIPRO-LEBIN', 'vertical_state': 'cruise', 'time_in_cell': np.float64(2280.0)}, {'flight_id': 'SQ10_B738_trajectory', 'timestamp': np.int64(1330), 'altitude': np.float64(35000.0), 'waypoint_segment': 'LIPRO-LEBIN', 'vertical_state': 'cruise', 'time_in_cell': np.float64(2270.0)}, {'flight_id': 'SQ10_B738_trajectory', 'timestamp': np.int64(1340), 'altitude': np.float64(35000.0), 'waypoint_segment': 'LIPRO-LEBIN', 'vertical_state': 'cruise', 'time_in_cell': np.float64(2260.0)}, {'flight_id': 'SQ10_B738_trajectory', 'timestamp': np.int64(1350), 'altitude': np.float64(35000.0), 'waypoint_segment': 'LIPRO-LEBIN', 'vertical_state': 'cruise', 'time_in_cell': np.float64(2250.0)}, {'flight_id': 'SQ10_B738_trajectory', 'timestamp': np.int64(1360), 'altitude': np.float64(35000.0), 'waypoint_segment': 'LIPRO-LEBIN', 'vertical_state': 'cruise', 'time_in_cell': np.float64(2240.0)}, {'flight_id': 'SQ10_B738_trajectory', 'timestamp': np.int64(1370), 'altitude': np.float64(35000.0), 'waypoint_segment': 'LIPRO-LEBIN', 'vertical_state': 'cruise', 'time_in_cell': np.float64(2230.0)}, {'flight_id': 'SQ10_B738_trajectory', 'timestamp': np.int64(1380), 'altitude': np.float64(35000.0), 'waypoint_segment': 'LIPRO-LEBIN', 'vertical_state': 'cruise', 'time_in_cell': np.float64(2220.0)}, {'flight_id': 'SQ10_B738_trajectory', 'timestamp': np.int64(1390), 'altitude': np.float64(35000.0), 'waypoint_segment': 'LIPRO-LEBIN', 'vertical_state': 'cruise', 'time_in_cell': np.float64(2210.0)}, {'flight_id': 'SQ10_B738_trajectory', 'timestamp': np.int64(1400), 'altitude': np.float64(35000.0), 'waypoint_segment': 'LIPRO-LEBIN', 'vertical_state': 'cruise', 'time_in_cell': np.float64(2200.0)}, {'flight_id': 'SQ10_B738_trajectory', 'timestamp': np.int64(1410), 'altitude': np.float64(35000.0), 'waypoint_segment': 'LIPRO-LEBIN', 'vertical_state': 'cruise', 'time_in_cell': np.float64(2190.0)}, {'flight_id': 'SQ10_B738_trajectory', 'timestamp': np.int64(1420), 'altitude': np.float64(35000.0), 'waypoint_segment': 'LIPRO-LEBIN', 'vertical_state': 'cruise', 'time_in_cell': np.float64(2180.0)}, {'flight_id': 'SQ10_B738_trajectory', 'timestamp': np.int64(1430), 'altitude': np.float64(35000.0), 'waypoint_segment': 'LIPRO-LEBIN', 'vertical_state': 'cruise', 'time_in_cell': np.float64(2170.0)}, {'flight_id': 'SQ10_B738_trajectory', 'timestamp': np.int64(1440), 'altitude': np.float64(35000.0), 'waypoint_segment': 'LIPRO-LEBIN', 'vertical_state': 'cruise', 'time_in_cell': np.float64(2160.0)}, {'flight_id': 'SQ10_B738_trajectory', 'timestamp': np.int64(1450), 'altitude': np.float64(35000.0), 'waypoint_segment': 'LIPRO-LEBIN', 'vertical_state': 'cruise', 'time_in_cell': np.float64(2150.0)}, {'flight_id': 'SQ10_B738_trajector ...
# key: (np.int64(9), np.int64(2), np.int64(6), np.int64(0)), Value: Cell4D(x_min=np.float64(105.67194399999995), x_max=np.float64(106.00527733333328), y_min=np.float64(2.827777666666667), y_max=np.float64(3.1611110000000004), z_min=np.float64(34333.33000000001), z_max=np.float64(37333.330000000016), t_min=np.float64(0.0), t_max=np.float64(3600.0), aircraft_records=[{'flight_id': 'SQ10_B738_trajectory', 'timestamp': np.int64(1500), 'altitude': np.float64(35000.0), 'waypoint_segment': 'LIPRO-LEBIN', 'vertical_state': 'cruise', 'time_in_cell': np.float64(2100.0)}, {'flight_id': 'SQ10_B738_trajectory', 'timestamp': np.int64(1510), 'altitude': np.float64(35000.0), 'waypoint_segment': 'LIPRO-LEBIN', 'vertical_state': 'cruise', 'time_in_cell': np.float64(2090.0)}, {'flight_id': 'SQ10_B738_trajectory', 'timestamp': np.int64(1520), 'altitude': np.float64(35000.0), 'waypoint_segment': 'LIPRO-LEBIN', 'vertical_state': 'cruise', 'time_in_cell': np.float64(2080.0)}, {'flight_id': 'SQ10_B738_trajectory', 'timestamp': np.int64(1530), 'altitude': np.float64(35000.0), 'waypoint_segment': 'LIPRO-LEBIN', 'vertical_state': 'cruise', 'time_in_cell': np.float64(2070.0)}, {'flight_id': 'SQ10_B738_trajectory', 'timestamp': np.int64(1540), 'altitude': np.float64(35000.0), 'waypoint_segment': 'LIPRO-LEBIN', 'vertical_state': 'cruise', 'time_in_cell': np.float64(2060.0)}, {'flight_id': 'SQ10_B738_trajectory', 'timestamp': np.int64(1550), 'altitude': np.float64(35000.0), 'waypoint_segment': 'LIPRO-LEBIN', 'vertical_state': 'cruise', 'time_in_cell': np.float64(2050.0)}, {'flight_id': 'SQ10_B738_trajectory', 'timestamp': np.int64(1560), 'altitude': np.float64(35000.0), 'waypoint_segment': 'LIPRO-LEBIN', 'vertical_state': 'cruise', 'time_in_cell': np.float64(2040.0)}, {'flight_id': 'SQ10_B738_trajectory', 'timestamp': np.int64(1570), 'altitude': np.float64(35000.0), 'waypoint_segment': 'LIPRO-LEBIN', 'vertical_state': 'cruise', 'time_in_cell': np.float64(2030.0)}, {'flight_id': 'SQ10_B738_trajectory', 'timestamp': np.int64(1580), 'altitude': np.float64(35000.0), 'waypoint_segment': 'LIPRO-LEBIN', 'vertical_state': 'cruise', 'time_in_cell': np.float64(2020.0)}, {'flight_id': 'SQ10_B738_trajectory', 'timestamp': np.int64(1590), 'altitude': np.float64(35000.0), 'waypoint_segment': 'LIPRO-LEBIN', 'vertical_state': 'cruise', 'time_in_cell': np.float64(2010.0)}, {'flight_id': 'SQ10_B738_trajectory', 'timestamp': np.int64(1600), 'altitude': np.float64(35000.0), 'waypoint_segment': 'LIPRO-LEBIN', 'vertical_state': 'cruise', 'time_in_cell': np.float64(2000.0)}, {'flight_id': 'SQ10_B738_trajectory', 'timestamp': np.int64(1610), 'altitude': np.float64(35000.0), 'waypoint_segment': 'LIPRO-LEBIN', 'vertical_state': 'cruise', 'time_in_cell': np.float64(1990.0)}, {'flight_id': 'SQ10_B738_trajectory', 'timestamp': np.int64(1620), 'altitude': np.float64(35000.0), 'waypoint_segment': 'LIPRO-LEBIN', 'vertical_state': 'cruise', 'time_in_cell': np.float64(1980.0)}, {'flight_id': 'SQ10_B738_trajectory', 'timestamp': np.int64(1630), 'altitude': np.float64(35000.0), 'waypoint_segment': 'LIPRO-LEBIN', 'vertical_state': 'cruise', 'time_in_cell': np.float64(1970.0)}, {'flight_id': 'SQ10_B738_trajectory', 'timestamp': np.int64(1640), 'altitude': np.float64(35000.0), 'waypoint_segment': 'LIPRO-LEBIN', 'vertical_state': 'cruise', 'time_in_cell': np.float64(1960.0)}, {'flight_id': 'SQ11_B738_trajectory', 'timestamp': np.int64(1750), 'altitude': np.float64(35000.0), 'waypoint_segment': 'LIPRO-LEBIN', 'vertical_state': 'cruise', 'time_in_cell': np.float64(1850.0)}, {'flight_id': 'SQ11_B738_trajectory', 'timestamp': np.int64(1760), 'altitude': np.float64(35000.0), 'waypoint_segment': 'LIPRO-LEBIN', 'vertical_state': 'cruise', 'time_in_cell': np.float64(1840.0)}, {'flight_id': 'SQ11_B738_trajectory', 'timestamp': np.int64(1770), 'altitude': np.float64(35000.0), 'waypoint_segment': 'LIPRO-LEBIN', 'vertical_state': 'cruise', 'time_in_cell': np.float64(1830.0)}, {'flight_id': 'SQ11_B738_trajector ...
# key: (np.int64(9), np.int64(3), np.int64(6), np.int64(0)), Value: Cell4D(x_min=np.float64(105.67194399999995), x_max=np.float64(106.00527733333328), y_min=np.float64(3.1611110000000004), y_max=np.float64(3.494444333333334), z_min=np.float64(34333.33000000001), z_max=np.float64(37333.330000000016), t_min=np.float64(0.0), t_max=np.float64(3600.0), aircraft_records=[{'flight_id': 'SQ10_B738_trajectory', 'timestamp': np.int64(1650), 'altitude': np.float64(35000.0), 'waypoint_segment': 'LIPRO-LEBIN', 'vertical_state': 'cruise', 'time_in_cell': np.float64(1950.0)}, {'flight_id': 'SQ10_B738_trajectory', 'timestamp': np.int64(1660), 'altitude': np.float64(35000.0), 'waypoint_segment': 'LIPRO-LEBIN', 'vertical_state': 'cruise', 'time_in_cell': np.float64(1940.0)}, {'flight_id': 'SQ10_B738_trajectory', 'timestamp': np.int64(1670), 'altitude': np.float64(35000.0), 'waypoint_segment': 'LIPRO-LEBIN', 'vertical_state': 'cruise', 'time_in_cell': np.float64(1930.0)}, {'flight_id': 'SQ10_B738_trajectory', 'timestamp': np.int64(1680), 'altitude': np.float64(35000.0), 'waypoint_segment': 'LIPRO-LEBIN', 'vertical_state': 'cruise', 'time_in_cell': np.float64(1920.0)}, {'flight_id': 'SQ10_B738_trajectory', 'timestamp': np.int64(1690), 'altitude': np.float64(35000.0), 'waypoint_segment': 'LIPRO-LEBIN', 'vertical_state': 'cruise', 'time_in_cell': np.float64(1910.0)}, {'flight_id': 'SQ10_B738_trajectory', 'timestamp': np.int64(1700), 'altitude': np.float64(35000.0), 'waypoint_segment': 'LIPRO-LEBIN', 'vertical_state': 'cruise', 'time_in_cell': np.float64(1900.0)}, {'flight_id': 'SQ10_B738_trajectory', 'timestamp': np.int64(1710), 'altitude': np.float64(35000.0), 'waypoint_segment': 'LIPRO-LEBIN', 'vertical_state': 'cruise', 'time_in_cell': np.float64(1890.0)}, {'flight_id': 'SQ11_B738_trajectory', 'timestamp': np.int64(1900), 'altitude': np.float64(35000.0), 'waypoint_segment': 'LIPRO-LEBIN', 'vertical_state': 'cruise', 'time_in_cell': np.float64(1700.0)}, {'flight_id': 'SQ11_B738_trajectory', 'timestamp': np.int64(1910), 'altitude': np.float64(35000.0), 'waypoint_segment': 'LIPRO-LEBIN', 'vertical_state': 'cruise', 'time_in_cell': np.float64(1690.0)}, {'flight_id': 'SQ11_B738_trajectory', 'timestamp': np.int64(1920), 'altitude': np.float64(35000.0), 'waypoint_segment': 'LIPRO-LEBIN', 'vertical_state': 'cruise', 'time_in_cell': np.float64(1680.0)}, {'flight_id': 'SQ11_B738_trajectory', 'timestamp': np.int64(1930), 'altitude': np.float64(35000.0), 'waypoint_segment': 'LIPRO-LEBIN', 'vertical_state': 'cruise', 'time_in_cell': np.float64(1670.0)}, {'flight_id': 'SQ11_B738_trajectory', 'timestamp': np.int64(1940), 'altitude': np.float64(35000.0), 'waypoint_segment': 'LIPRO-LEBIN', 'vertical_state': 'cruise', 'time_in_cell': np.float64(1660.0)}, {'flight_id': 'SQ11_B738_trajectory', 'timestamp': np.int64(1950), 'altitude': np.float64(35000.0), 'waypoint_segment': 'LIPRO-LEBIN', 'vertical_state': 'cruise', 'time_in_cell': np.float64(1650.0)}, {'flight_id': 'SQ11_B738_trajectory', 'timestamp': np.int64(1960), 'altitude': np.float64(35000.0), 'waypoint_segment': 'LIPRO-LEBIN', 'vertical_state': 'cruise', 'time_in_cell': np.float64(1640.0)}])
# key: (np.int64(10), np.int64(3), np.int64(6), np.int64(0)), Value: Cell4D(x_min=np.float64(106.00527733333328), x_max=np.float64(106.33861066666661), y_min=np.float64(3.1611110000000004), y_max=np.float64(3.494444333333334), z_min=np.float64(34333.33000000001), z_max=np.float64(37333.330000000016), t_min=np.float64(0.0), t_max=np.float64(3600.0), aircraft_records=[{'flight_id': 'SQ10_B738_trajectory', 'timestamp': np.int64(1720), 'altitude': np.float64(35000.0), 'waypoint_segment': 'LIPRO-LEBIN', 'vertical_state': 'cruise', 'time_in_cell': np.float64(1880.0)}, {'flight_id': 'SQ10_B738_trajectory', 'timestamp': np.int64(1730), 'altitude': np.float64(35000.0), 'waypoint_segment': 'LIPRO-LEBIN', 'vertical_state': 'cruise', 'time_in_cell': np.float64(1870.0)}, {'flight_id': 'SQ10_B738_trajectory', 'timestamp': np.int64(1740), 'altitude': np.float64(35000.0), 'waypoint_segment': 'LIPRO-LEBIN', 'vertical_state': 'cruise', 'time_in_cell': np.float64(1860.0)}, {'flight_id': 'SQ10_B738_trajectory', 'timestamp': np.int64(1750), 'altitude': np.float64(35000.0), 'waypoint_segment': 'LIPRO-LEBIN', 'vertical_state': 'cruise', 'time_in_cell': np.float64(1850.0)}, {'flight_id': 'SQ10_B738_trajectory', 'timestamp': np.int64(1760), 'altitude': np.float64(35000.0), 'waypoint_segment': 'LIPRO-LEBIN', 'vertical_state': 'cruise', 'time_in_cell': np.float64(1840.0)}, {'flight_id': 'SQ10_B738_trajectory', 'timestamp': np.int64(1770), 'altitude': np.float64(35000.0), 'waypoint_segment': 'LIPRO-LEBIN', 'vertical_state': 'cruise', 'time_in_cell': np.float64(1830.0)}, {'flight_id': 'SQ10_B738_trajectory', 'timestamp': np.int64(1780), 'altitude': np.float64(35000.0), 'waypoint_segment': 'LIPRO-LEBIN', 'vertical_state': 'cruise', 'time_in_cell': np.float64(1820.0)}, {'flight_id': 'SQ10_B738_trajectory', 'timestamp': np.int64(1790), 'altitude': np.float64(35000.0), 'waypoint_segment': 'LEBIN-ONAPO', 'vertical_state': 'cruise', 'time_in_cell': np.float64(1810.0)}, {'flight_id': 'SQ10_B738_trajectory', 'timestamp': np.int64(1800), 'altitude': np.float64(35000.0), 'waypoint_segment': 'LEBIN-ONAPO', 'vertical_state': 'cruise', 'time_in_cell': np.float64(1800.0)}, {'flight_id': 'SQ10_B738_trajectory', 'timestamp': np.int64(1810), 'altitude': np.float64(35000.0), 'waypoint_segment': 'LEBIN-ONAPO', 'vertical_state': 'cruise', 'time_in_cell': np.float64(1790.0)}, {'flight_id': 'SQ10_B738_trajectory', 'timestamp': np.int64(1820), 'altitude': np.float64(35000.0), 'waypoint_segment': 'LEBIN-ONAPO', 'vertical_state': 'cruise', 'time_in_cell': np.float64(1780.0)}, {'flight_id': 'SQ10_B738_trajectory', 'timestamp': np.int64(1830), 'altitude': np.float64(35000.0), 'waypoint_segment': 'LEBIN-ONAPO', 'vertical_state': 'cruise', 'time_in_cell': np.float64(1770.0)}, {'flight_id': 'SQ10_B738_trajectory', 'timestamp': np.int64(1840), 'altitude': np.float64(35000.0), 'waypoint_segment': 'LEBIN-ONAPO', 'vertical_state': 'cruise', 'time_in_cell': np.float64(1760.0)}, {'flight_id': 'SQ10_B738_trajectory', 'timestamp': np.int64(1850), 'altitude': np.float64(35000.0), 'waypoint_segment': 'LEBIN-ONAPO', 'vertical_state': 'cruise', 'time_in_cell': np.float64(1750.0)}, {'flight_id': 'SQ10_B738_trajectory', 'timestamp': np.int64(1860), 'altitude': np.float64(35000.0), 'waypoint_segment': 'LEBIN-ONAPO', 'vertical_state': 'cruise', 'time_in_cell': np.float64(1740.0)}, {'flight_id': 'SQ10_B738_trajectory', 'timestamp': np.int64(1870), 'altitude': np.float64(35000.0), 'waypoint_segment': 'LEBIN-ONAPO', 'vertical_state': 'cruise', 'time_in_cell': np.float64(1730.0)}, {'flight_id': 'SQ10_B738_trajectory', 'timestamp': np.int64(1880), 'altitude': np.float64(35000.0), 'waypoint_segment': 'LEBIN-ONAPO', 'vertical_state': 'cruise', 'time_in_cell': np.float64(1720.0)}, {'flight_id': 'SQ10_B738_trajectory', 'timestamp': np.int64(1890), 'altitude': np.float64(35000.0), 'waypoint_segment': 'LEBIN-ONAPO', 'vertical_state': 'cruise', 'time_in_cell': np.float64(1710.0)}, {'flight_id': 'SQ10_B738_trajecto ...
# key: (np.int64(11), np.int64(3), np.int64(6), np.int64(0)), Value: Cell4D(x_min=np.float64(106.33861066666661), x_max=np.float64(106.67194399999994), y_min=np.float64(3.1611110000000004), y_max=np.float64(3.494444333333334), z_min=np.float64(34333.33000000001), z_max=np.float64(37333.330000000016), t_min=np.float64(0.0), t_max=np.float64(3600.0), aircraft_records=[{'flight_id': 'SQ10_B738_trajectory', 'timestamp': np.int64(1950), 'altitude': np.float64(35000.0), 'waypoint_segment': 'LEBIN-ONAPO', 'vertical_state': 'cruise', 'time_in_cell': np.float64(1650.0)}, {'flight_id': 'SQ10_B738_trajectory', 'timestamp': np.int64(1960), 'altitude': np.float64(35000.0), 'waypoint_segment': 'LEBIN-ONAPO', 'vertical_state': 'cruise', 'time_in_cell': np.float64(1640.0)}, {'flight_id': 'SQ10_B738_trajectory', 'timestamp': np.int64(1970), 'altitude': np.float64(35000.0), 'waypoint_segment': 'LEBIN-ONAPO', 'vertical_state': 'cruise', 'time_in_cell': np.float64(1630.0)}, {'flight_id': 'SQ10_B738_trajectory', 'timestamp': np.int64(1980), 'altitude': np.float64(35000.0), 'waypoint_segment': 'LEBIN-ONAPO', 'vertical_state': 'cruise', 'time_in_cell': np.float64(1620.0)}, {'flight_id': 'SQ10_B738_trajectory', 'timestamp': np.int64(1990), 'altitude': np.float64(35000.0), 'waypoint_segment': 'ONAPO-LUSMO', 'vertical_state': 'cruise', 'time_in_cell': np.float64(1610.0)}, {'flight_id': 'SQ10_B738_trajectory', 'timestamp': np.int64(2000), 'altitude': np.float64(35000.0), 'waypoint_segment': 'ONAPO-LUSMO', 'vertical_state': 'cruise', 'time_in_cell': np.float64(1600.0)}, {'flight_id': 'SQ10_B738_trajectory', 'timestamp': np.int64(2010), 'altitude': np.float64(35000.0), 'waypoint_segment': 'ONAPO-LUSMO', 'vertical_state': 'cruise', 'time_in_cell': np.float64(1590.0)}, {'flight_id': 'SQ10_B738_trajectory', 'timestamp': np.int64(2020), 'altitude': np.float64(35000.0), 'waypoint_segment': 'ONAPO-LUSMO', 'vertical_state': 'cruise', 'time_in_cell': np.float64(1580.0)}, {'flight_id': 'SQ10_B738_trajectory', 'timestamp': np.int64(2030), 'altitude': np.float64(35000.0), 'waypoint_segment': 'ONAPO-LUSMO', 'vertical_state': 'cruise', 'time_in_cell': np.float64(1570.0)}, {'flight_id': 'SQ10_B738_trajectory', 'timestamp': np.int64(2040), 'altitude': np.float64(35000.0), 'waypoint_segment': 'ONAPO-LUSMO', 'vertical_state': 'cruise', 'time_in_cell': np.float64(1560.0)}, {'flight_id': 'SQ10_B738_trajectory', 'timestamp': np.int64(2050), 'altitude': np.float64(35000.0), 'waypoint_segment': 'ONAPO-LUSMO', 'vertical_state': 'cruise', 'time_in_cell': np.float64(1550.0)}, {'flight_id': 'SQ10_B738_trajectory', 'timestamp': np.int64(2060), 'altitude': np.float64(35000.0), 'waypoint_segment': 'ONAPO-LUSMO', 'vertical_state': 'cruise', 'time_in_cell': np.float64(1540.0)}, {'flight_id': 'SQ10_B738_trajectory', 'timestamp': np.int64(2070), 'altitude': np.float64(35000.0), 'waypoint_segment': 'ONAPO-LUSMO', 'vertical_state': 'cruise', 'time_in_cell': np.float64(1530.0)}, {'flight_id': 'SQ10_B738_trajectory', 'timestamp': np.int64(2080), 'altitude': np.float64(35000.0), 'waypoint_segment': 'ONAPO-LUSMO', 'vertical_state': 'cruise', 'time_in_cell': np.float64(1520.0)}, {'flight_id': 'SQ10_B738_trajectory', 'timestamp': np.int64(2090), 'altitude': np.float64(35000.0), 'waypoint_segment': 'ONAPO-LUSMO', 'vertical_state': 'cruise', 'time_in_cell': np.float64(1510.0)}, {'flight_id': 'SQ10_B738_trajectory', 'timestamp': np.int64(2100), 'altitude': np.float64(35000.0), 'waypoint_segment': 'ONAPO-LUSMO', 'vertical_state': 'cruise', 'time_in_cell': np.float64(1500.0)}, {'flight_id': 'SQ10_B738_trajectory', 'timestamp': np.int64(2110), 'altitude': np.float64(35000.0), 'waypoint_segment': 'ONAPO-LUSMO', 'vertical_state': 'cruise', 'time_in_cell': np.float64(1490.0)}, {'flight_id': 'SQ10_B738_trajectory', 'timestamp': np.int64(2120), 'altitude': np.float64(35000.0), 'waypoint_segment': 'ONAPO-LUSMO', 'vertical_state': 'cruise', 'time_in_cell': np.float64(1480.0)}, {'flight_id': 'SQ10_B738_trajecto ...
# key: (np.int64(12), np.int64(3), np.int64(6), np.int64(0)), Value: Cell4D(x_min=np.float64(106.67194399999994), x_max=np.float64(107.00527733333327), y_min=np.float64(3.1611110000000004), y_max=np.float64(3.494444333333334), z_min=np.float64(34333.33000000001), z_max=np.float64(37333.330000000016), t_min=np.float64(0.0), t_max=np.float64(3600.0), aircraft_records=[{'flight_id': 'SQ10_B738_trajectory', 'timestamp': np.int64(2180), 'altitude': np.float64(35000.0), 'waypoint_segment': 'ONAPO-LUSMO', 'vertical_state': 'cruise', 'time_in_cell': np.float64(1420.0)}, {'flight_id': 'SQ10_B738_trajectory', 'timestamp': np.int64(2190), 'altitude': np.float64(35000.0), 'waypoint_segment': 'ONAPO-LUSMO', 'vertical_state': 'cruise', 'time_in_cell': np.float64(1410.0)}, {'flight_id': 'SQ10_B738_trajectory', 'timestamp': np.int64(2200), 'altitude': np.float64(35000.0), 'waypoint_segment': 'ONAPO-LUSMO', 'vertical_state': 'cruise', 'time_in_cell': np.float64(1400.0)}, {'flight_id': 'SQ10_B738_trajectory', 'timestamp': np.int64(2210), 'altitude': np.float64(35000.0), 'waypoint_segment': 'ONAPO-LUSMO', 'vertical_state': 'cruise', 'time_in_cell': np.float64(1390.0)}, {'flight_id': 'SQ10_B738_trajectory', 'timestamp': np.int64(2220), 'altitude': np.float64(35000.0), 'waypoint_segment': 'ONAPO-LUSMO', 'vertical_state': 'cruise', 'time_in_cell': np.float64(1380.0)}, {'flight_id': 'SQ11_B738_trajectory', 'timestamp': np.int64(2430), 'altitude': np.float64(35000.0), 'waypoint_segment': 'ONAPO-LUSMO', 'vertical_state': 'cruise', 'time_in_cell': np.float64(1170.0)}, {'flight_id': 'SQ11_B738_trajectory', 'timestamp': np.int64(2440), 'altitude': np.float64(35000.0), 'waypoint_segment': 'ONAPO-LUSMO', 'vertical_state': 'cruise', 'time_in_cell': np.float64(1160.0)}, {'flight_id': 'SQ11_B738_trajectory', 'timestamp': np.int64(2450), 'altitude': np.float64(35000.0), 'waypoint_segment': 'ONAPO-LUSMO', 'vertical_state': 'cruise', 'time_in_cell': np.float64(1150.0)}, {'flight_id': 'SQ11_B738_trajectory', 'timestamp': np.int64(2460), 'altitude': np.float64(35000.0), 'waypoint_segment': 'ONAPO-LUSMO', 'vertical_state': 'cruise', 'time_in_cell': np.float64(1140.0)}, {'flight_id': 'SQ11_B738_trajectory', 'timestamp': np.int64(2470), 'altitude': np.float64(35000.0), 'waypoint_segment': 'ONAPO-LUSMO', 'vertical_state': 'cruise', 'time_in_cell': np.float64(1130.0)}])
# ...
# key: (np.int64(9), np.int64(1), np.int64(6), np.int64(0)), Value: Cell4D(x_min=np.float64(105.67194399999995), x_max=np.float64(106.00527733333328), y_min=np.float64(2.4944443333333335), y_max=np.float64(2.827777666666667), z_min=np.float64(34333.33000000001), z_max=np.float64(37333.330000000016), t_min=np.float64(0.0), t_max=np.float64(3600.0), aircraft_records=[{'flight_id': 'SQ15_B738_trajectory', 'timestamp': np.int64(1200), 'altitude': np.float64(35000.0), 'waypoint_segment': 'VERIN-BUNTO', 'vertical_state': 'cruise', 'time_in_cell': np.float64(2400.0)}, {'flight_id': 'SQ15_B738_trajectory', 'timestamp': np.int64(1210), 'altitude': np.float64(35000.0), 'waypoint_segment': 'VERIN-BUNTO', 'vertical_state': 'cruise', 'time_in_cell': np.float64(2390.0)}, {'flight_id': 'SQ15_B738_trajectory', 'timestamp': np.int64(1220), 'altitude': np.float64(35000.0), 'waypoint_segment': 'VERIN-BUNTO', 'vertical_state': 'cruise', 'time_in_cell': np.float64(2380.0)}, {'flight_id': 'SQ15_B738_trajectory', 'timestamp': np.int64(1230), 'altitude': np.float64(35000.0), 'waypoint_segment': 'VERIN-BUNTO', 'vertical_state': 'cruise', 'time_in_cell': np.float64(2370.0)}, {'flight_id': 'SQ15_B738_trajectory', 'timestamp': np.int64(1240), 'altitude': np.float64(35000.0), 'waypoint_segment': 'VERIN-BUNTO', 'vertical_state': 'cruise', 'time_in_cell': np.float64(2360.0)}, {'flight_id': 'SQ15_B738_trajectory', 'timestamp': np.int64(1250), 'altitude': np.float64(35000.0), 'waypoint_segment': 'VERIN-BUNTO', 'vertical_state': 'cruise', 'time_in_cell': np.float64(2350.0)}, {'flight_id': 'SQ15_B738_trajectory', 'timestamp': np.int64(1260), 'altitude': np.float64(35000.0), 'waypoint_segment': 'VERIN-BUNTO', 'vertical_state': 'cruise', 'time_in_cell': np.float64(2340.0)}, {'flight_id': 'SQ15_B738_trajectory', 'timestamp': np.int64(1270), 'altitude': np.float64(35000.0), 'waypoint_segment': 'VERIN-BUNTO', 'vertical_state': 'cruise', 'time_in_cell': np.float64(2330.0)}, {'flight_id': 'SQ15_B738_trajectory', 'timestamp': np.int64(1280), 'altitude': np.float64(35000.0), 'waypoint_segment': 'VERIN-BUNTO', 'vertical_state': 'cruise', 'time_in_cell': np.float64(2320.0)}, {'flight_id': 'SQ15_B738_trajectory', 'timestamp': np.int64(1290), 'altitude': np.float64(35000.0), 'waypoint_segment': 'VERIN-BUNTO', 'vertical_state': 'cruise', 'time_in_cell': np.float64(2310.0)}, {'flight_id': 'SQ15_B738_trajectory', 'timestamp': np.int64(1300), 'altitude': np.float64(35000.0), 'waypoint_segment': 'VERIN-BUNTO', 'vertical_state': 'cruise', 'time_in_cell': np.float64(2300.0)}, {'flight_id': 'SQ15_B738_trajectory', 'timestamp': np.int64(1310), 'altitude': np.float64(35000.0), 'waypoint_segment': 'VERIN-BUNTO', 'vertical_state': 'cruise', 'time_in_cell': np.float64(2290.0)}, {'flight_id': 'SQ15_B738_trajectory', 'timestamp': np.int64(1320), 'altitude': np.float64(35000.0), 'waypoint_segment': 'VERIN-BUNTO', 'vertical_state': 'cruise', 'time_in_cell': np.float64(2280.0)}, {'flight_id': 'SQ15_B738_trajectory', 'timestamp': np.int64(1330), 'altitude': np.float64(35000.0), 'waypoint_segment': 'VERIN-BUNTO', 'vertical_state': 'cruise', 'time_in_cell': np.float64(2270.0)}, {'flight_id': 'SQ15_B738_trajectory', 'timestamp': np.int64(1340), 'altitude': np.float64(35000.0), 'waypoint_segment': 'VERIN-BUNTO', 'vertical_state': 'cruise', 'time_in_cell': np.float64(2260.0)}, {'flight_id': 'SQ15_B738_trajectory', 'timestamp': np.int64(1350), 'altitude': np.float64(35000.0), 'waypoint_segment': 'VERIN-BUNTO', 'vertical_state': 'cruise', 'time_in_cell': np.float64(2250.0)}, {'flight_id': 'SQ15_B738_trajectory', 'timestamp': np.int64(1360), 'altitude': np.float64(35000.0), 'waypoint_segment': 'VERIN-BUNTO', 'vertical_state': 'cruise', 'time_in_cell': np.float64(2240.0)}, {'flight_id': 'SQ15_B738_trajectory', 'timestamp': np.int64(1370), 'altitude': np.float64(35000.0), 'waypoint_segment': 'VERIN-BUNTO', 'vertical_state': 'cruise', 'time_in_cell': np.float64(2230.0)}, {'flight_id': 'SQ15_B738_trajector ...
# key: (np.int64(8), np.int64(1), np.int64(6), np.int64(0)), Value: Cell4D(x_min=np.float64(105.33861066666663), x_max=np.float64(105.67194399999995), y_min=np.float64(2.4944443333333335), y_max=np.float64(2.827777666666667), z_min=np.float64(34333.33000000001), z_max=np.float64(37333.330000000016), t_min=np.float64(0.0), t_max=np.float64(3600.0), aircraft_records=[{'flight_id': 'SQ15_B738_trajectory', 'timestamp': np.int64(1410), 'altitude': np.float64(35000.0), 'waypoint_segment': 'VERIN-BUNTO', 'vertical_state': 'cruise', 'time_in_cell': np.float64(2190.0)}, {'flight_id': 'SQ15_B738_trajectory', 'timestamp': np.int64(1420), 'altitude': np.float64(35000.0), 'waypoint_segment': 'VERIN-BUNTO', 'vertical_state': 'cruise', 'time_in_cell': np.float64(2180.0)}, {'flight_id': 'SQ15_B738_trajectory', 'timestamp': np.int64(1430), 'altitude': np.float64(35000.0), 'waypoint_segment': 'VERIN-BUNTO', 'vertical_state': 'cruise', 'time_in_cell': np.float64(2170.0)}, {'flight_id': 'SQ15_B738_trajectory', 'timestamp': np.int64(1440), 'altitude': np.float64(35000.0), 'waypoint_segment': 'VERIN-BUNTO', 'vertical_state': 'cruise', 'time_in_cell': np.float64(2160.0)}, {'flight_id': 'SQ15_B738_trajectory', 'timestamp': np.int64(1450), 'altitude': np.float64(35000.0), 'waypoint_segment': 'VERIN-BUNTO', 'vertical_state': 'cruise', 'time_in_cell': np.float64(2150.0)}, {'flight_id': 'SQ15_B738_trajectory', 'timestamp': np.int64(1460), 'altitude': np.float64(35000.0), 'waypoint_segment': 'VERIN-BUNTO', 'vertical_state': 'cruise', 'time_in_cell': np.float64(2140.0)}, {'flight_id': 'SQ15_B738_trajectory', 'timestamp': np.int64(1470), 'altitude': np.float64(35000.0), 'waypoint_segment': 'VERIN-BUNTO', 'vertical_state': 'cruise', 'time_in_cell': np.float64(2130.0)}, {'flight_id': 'SQ15_B738_trajectory', 'timestamp': np.int64(1480), 'altitude': np.float64(35000.0), 'waypoint_segment': 'VERIN-BUNTO', 'vertical_state': 'cruise', 'time_in_cell': np.float64(2120.0)}, {'flight_id': 'SQ15_B738_trajectory', 'timestamp': np.int64(1490), 'altitude': np.float64(35000.0), 'waypoint_segment': 'VERIN-BUNTO', 'vertical_state': 'cruise', 'time_in_cell': np.float64(2110.0)}, {'flight_id': 'SQ15_B738_trajectory', 'timestamp': np.int64(1500), 'altitude': np.float64(35000.0), 'waypoint_segment': 'VERIN-BUNTO', 'vertical_state': 'cruise', 'time_in_cell': np.float64(2100.0)}, {'flight_id': 'SQ15_B738_trajectory', 'timestamp': np.int64(1510), 'altitude': np.float64(35000.0), 'waypoint_segment': 'VERIN-BUNTO', 'vertical_state': 'cruise', 'time_in_cell': np.float64(2090.0)}, {'flight_id': 'SQ15_B738_trajectory', 'timestamp': np.int64(1520), 'altitude': np.float64(35000.0), 'waypoint_segment': 'VERIN-BUNTO', 'vertical_state': 'cruise', 'time_in_cell': np.float64(2080.0)}, {'flight_id': 'SQ15_B738_trajectory', 'timestamp': np.int64(1530), 'altitude': np.float64(35000.0), 'waypoint_segment': 'VERIN-BUNTO', 'vertical_state': 'cruise', 'time_in_cell': np.float64(2070.0)}, {'flight_id': 'SQ15_B738_trajectory', 'timestamp': np.int64(1540), 'altitude': np.float64(35000.0), 'waypoint_segment': 'VERIN-BUNTO', 'vertical_state': 'cruise', 'time_in_cell': np.float64(2060.0)}, {'flight_id': 'SQ15_B738_trajectory', 'timestamp': np.int64(1550), 'altitude': np.float64(35000.0), 'waypoint_segment': 'VERIN-BUNTO', 'vertical_state': 'cruise', 'time_in_cell': np.float64(2050.0)}, {'flight_id': 'SQ16_B738_trajectory', 'timestamp': np.int64(1560), 'altitude': np.float64(35000.0), 'waypoint_segment': 'VERIN-BUNTO', 'vertical_state': 'cruise', 'time_in_cell': np.float64(2040.0)}, {'flight_id': 'SQ16_B738_trajectory', 'timestamp': np.int64(1570), 'altitude': np.float64(35000.0), 'waypoint_segment': 'VERIN-BUNTO', 'vertical_state': 'cruise', 'time_in_cell': np.float64(2030.0)}, {'flight_id': 'SQ16_B738_trajectory', 'timestamp': np.int64(1580), 'altitude': np.float64(35000.0), 'waypoint_segment': 'VERIN-BUNTO', 'vertical_state': 'cruise', 'time_in_cell': np.float64(2020.0)}, {'flight_id': 'SQ16_B738_trajector ...
# key: (np.int64(6), np.int64(2), np.int64(6), np.int64(0)), Value: Cell4D(x_min=np.float64(104.67194399999997), x_max=np.float64(105.0052773333333), y_min=np.float64(2.827777666666667), y_max=np.float64(3.1611110000000004), z_min=np.float64(34333.33000000001), z_max=np.float64(37333.330000000016), t_min=np.float64(0.0), t_max=np.float64(3600.0), aircraft_records=[{'flight_id': 'SQ15_B738_trajectory', 'timestamp': np.int64(1850), 'altitude': np.float64(35000.0), 'waypoint_segment': 'LIPRO-KILOT', 'vertical_state': 'cruise', 'time_in_cell': np.float64(1750.0)}, {'flight_id': 'SQ15_B738_trajectory', 'timestamp': np.int64(1860), 'altitude': np.float64(35000.0), 'waypoint_segment': 'LIPRO-KILOT', 'vertical_state': 'cruise', 'time_in_cell': np.float64(1740.0)}, {'flight_id': 'SQ15_B738_trajectory', 'timestamp': np.int64(1870), 'altitude': np.float64(35000.0), 'waypoint_segment': 'LIPRO-KILOT', 'vertical_state': 'cruise', 'time_in_cell': np.float64(1730.0)}, {'flight_id': 'SQ15_B738_trajectory', 'timestamp': np.int64(1880), 'altitude': np.float64(35000.0), 'waypoint_segment': 'LIPRO-KILOT', 'vertical_state': 'cruise', 'time_in_cell': np.float64(1720.0)}, {'flight_id': 'SQ15_B738_trajectory', 'timestamp': np.int64(1890), 'altitude': np.float64(35000.0), 'waypoint_segment': 'LIPRO-KILOT', 'vertical_state': 'cruise', 'time_in_cell': np.float64(1710.0)}, {'flight_id': 'SQ15_B738_trajectory', 'timestamp': np.int64(1900), 'altitude': np.float64(35000.0), 'waypoint_segment': 'LIPRO-KILOT', 'vertical_state': 'cruise', 'time_in_cell': np.float64(1700.0)}, {'flight_id': 'SQ15_B738_trajectory', 'timestamp': np.int64(1910), 'altitude': np.float64(35000.0), 'waypoint_segment': 'LIPRO-KILOT', 'vertical_state': 'cruise', 'time_in_cell': np.float64(1690.0)}, {'flight_id': 'SQ15_B738_trajectory', 'timestamp': np.int64(1920), 'altitude': np.float64(35000.0), 'waypoint_segment': 'LIPRO-KILOT', 'vertical_state': 'cruise', 'time_in_cell': np.float64(1680.0)}, {'flight_id': 'SQ15_B738_trajectory', 'timestamp': np.int64(1930), 'altitude': np.float64(35000.0), 'waypoint_segment': 'LIPRO-KILOT', 'vertical_state': 'cruise', 'time_in_cell': np.float64(1670.0)}, {'flight_id': 'SQ15_B738_trajectory', 'timestamp': np.int64(1940), 'altitude': np.float64(35000.0), 'waypoint_segment': 'LIPRO-KILOT', 'vertical_state': 'cruise', 'time_in_cell': np.float64(1660.0)}, {'flight_id': 'SQ15_B738_trajectory', 'timestamp': np.int64(1950), 'altitude': np.float64(35000.0), 'waypoint_segment': 'LIPRO-KILOT', 'vertical_state': 'cruise', 'time_in_cell': np.float64(1650.0)}, {'flight_id': 'SQ15_B738_trajectory', 'timestamp': np.int64(1960), 'altitude': np.float64(35000.0), 'waypoint_segment': 'LIPRO-KILOT', 'vertical_state': 'cruise', 'time_in_cell': np.float64(1640.0)}, {'flight_id': 'SQ15_B738_trajectory', 'timestamp': np.int64(1970), 'altitude': np.float64(35000.0), 'waypoint_segment': 'LIPRO-KILOT', 'vertical_state': 'cruise', 'time_in_cell': np.float64(1630.0)}, {'flight_id': 'SQ15_B738_trajectory', 'timestamp': np.int64(1980), 'altitude': np.float64(35000.0), 'waypoint_segment': 'LIPRO-KILOT', 'vertical_state': 'cruise', 'time_in_cell': np.float64(1620.0)}, {'flight_id': 'SQ15_B738_trajectory', 'timestamp': np.int64(1990), 'altitude': np.float64(35000.0), 'waypoint_segment': 'LIPRO-KILOT', 'vertical_state': 'cruise', 'time_in_cell': np.float64(1610.0)}, {'flight_id': 'SQ15_B738_trajectory', 'timestamp': np.int64(2000), 'altitude': np.float64(35000.0), 'waypoint_segment': 'LIPRO-KILOT', 'vertical_state': 'cruise', 'time_in_cell': np.float64(1600.0)}, {'flight_id': 'SQ15_B738_trajectory', 'timestamp': np.int64(2010), 'altitude': np.float64(35000.0), 'waypoint_segment': 'LIPRO-KILOT', 'vertical_state': 'cruise', 'time_in_cell': np.float64(1590.0)}, {'flight_id': 'SQ15_B738_trajectory', 'timestamp': np.int64(2020), 'altitude': np.float64(35000.0), 'waypoint_segment': 'LIPRO-KILOT', 'vertical_state': 'cruise', 'time_in_cell': np.float64(1580.0)}, {'flight_id': 'SQ15_B738_trajectory ...

# %%
def calculate_airspace_complexity(trajectories_folder: str = 'aircraft_trajectories') -> Dict:
    """
    Calculate airspace complexity from all trajectory files in the specified folder
    """
    # Get all trajectory files from the folder
    trajectory_path = Path(trajectories_folder)
    trajectory_files = list(trajectory_path.glob("SQ*.csv"))
    
    if not trajectory_files:
        raise ValueError(f"No trajectory files found in {trajectories_folder}")
    
    print(f"Found {len(trajectory_files)} trajectory files")
    
    # Read all trajectories into a single DataFrame
    all_data = []
    for file in trajectory_files:
        print(f"Reading {file.name}")
        df = pd.read_csv(file)
        df['flight_id'] = file.stem  # Add flight ID from filename
        all_data.append(df)
    print(all_data.grouby('flight_id'))
    # Combine all trajectories
    all_trajectories = pd.concat(all_data, ignore_index=True)
    print(f"Total data points: {len(all_trajectories)}")
    
    # Initialize calculator and process data
    calculator = ComplexityCalculator()
    calculator.create_4d_grid(all_trajectories)
    metrics = calculator.calculate_complexity_metrics()
    
    return metrics

# %%
metrics = calculate_airspace_complexity()
metrics
# Out:
# Found 21 trajectory files
# Reading SQ17_B738_trajectory.csv
# Reading SQ111_A320_trajectory.csv
# Reading SQ115_B738_trajectory.csv
# Reading SQ112_A320_trajectory.csv
# Reading SQ118_B734_trajectory.csv
# Reading SQ14_A320_trajectory.csv
# Reading SQ119_B734_trajectory.csv
# Reading SQ110_A320_trajectory.csv
# Reading SQ114_B738_trajectory.csv
# Reading SQ117_B734_trajectory.csv
# Reading SQ13_A320_trajectory.csv
# Reading SQ18_B738_trajectory.csv
# Reading SQ15_A320_trajectory.csv
# Reading SQ11_B738_trajectory.csv
# Reading SQ120_B734_trajectory.csv
# Reading SQ113_B738_trajectory.csv
# Reading SQ16_B738_trajectory.csv
# Reading SQ19_B738_trajectory.csv
# Reading SQ116_B734_trajectory.csv
# Reading SQ10_B738_trajectory.csv
# Reading SQ12_B738_trajectory.csv
# Total data points: 4347
# {'adjusted_density': 0.16967175219600603,
#  'vertical_interactions_per_flight_hour': 0.006703652334719604,
#  'horizontal_interactions_per_flight_hour': 0.06310679611649817,
#  'speed_interactions_per_flight_hour': 0.04137771613499332,
#  'r_vdif': 0.03950953678474126,
#  'r_hdif': 0.37193460490463226,
#  'r_sdif': 0.24386920980926444,
#  'structural_index': 0.655313351498638,
#  'complexity_score': 0.1111881645862111,
#  'total_flight_hours': 12.016666666667906,
#  'number_of_cells': 3640}

# %%
metrics = calculate_airspace_complexity()
metrics
# Out:
# Found 19 trajectory files
# Reading SQ17_B738_trajectory.csv
# Reading SQ111_A320_trajectory.csv
# Reading SQ115_B738_trajectory.csv
# Reading SQ112_A320_trajectory.csv
# Reading SQ118_B734_trajectory.csv
# Reading SQ14_A320_trajectory.csv
# Reading SQ110_A320_trajectory.csv
# Reading SQ114_B738_trajectory.csv
# Reading SQ117_B734_trajectory.csv
# Reading SQ13_A320_trajectory.csv
# Reading SQ18_B738_trajectory.csv
# Reading SQ15_A320_trajectory.csv
# Reading SQ11_B738_trajectory.csv
# Reading SQ113_B738_trajectory.csv
# Reading SQ16_B738_trajectory.csv
# Reading SQ19_B738_trajectory.csv
# Reading SQ116_B734_trajectory.csv
# Reading SQ10_B738_trajectory.csv
# Reading SQ12_B738_trajectory.csv
# Total data points: 3987
# {'adjusted_density': 0.17893145161288507,
#  'vertical_interactions_per_flight_hour': 0.0017641129032256331,
#  'horizontal_interactions_per_flight_hour': 0.07459677419354084,
#  'speed_interactions_per_flight_hour': 0.05141129032257546,
#  'r_vdif': 0.009859154929577497,
#  'r_hdif': 0.4169014084507044,
#  'r_sdif': 0.287323943661972,
#  'structural_index': 0.7140845070422539,
#  'complexity_score': 0.12777217741934194,
#  'total_flight_hours': 11.022222222223306,
#  'number_of_cells': 3305}

# %%
trajectory_path = Path('aircraft_trajectories')
trajectory_files = list(trajectory_path.glob("SQ*.csv"))
all_data = []
for file in trajectory_files:
    print(f"Reading {file.name}")
    df = pd.read_csv(file)
    df['flight_id'] = file.stem  # Add flight ID from filename
    all_data.append(df)
    
all_trajectories = pd.concat(all_data, ignore_index=True)
all_trajectories

# %%
c = ComplexityCalculator()
grid = c.create_4d_grid(all_trajectories)

# %%
type(grid)

# %%
for metric, value in metrics.items():
    print(f"{metric}: {value:.4f}")

# %%
# Example usage:
def calculate_airspace_complexity(trajectory_files: List[str]) -> Dict:
    """Calculate airspace complexity from trajectory files"""
    # Read trajectories
    trajectories = []
    for file in trajectory_files:
        df = pd.read_csv(file)
        trajectories.append(df)
    
    # Initialize calculator
    calculator = ComplexityCalculator()
    
    # Create 4D grid and assign aircraft
    calculator.create_4d_grid(trajectories)
    
    # Calculate complexity metrics
    metrics = calculator.calculate_complexity_metrics()
    
    return metrics

# %%
import pandas as pd
import numpy as np
from pathlib import Path

class CellAnalyzer:
    def __init__(self, calculator):
        self.calculator = calculator

    def print_cell_summary(self):
        """Print summary statistics about all cells"""
        print(f"\nTotal number of cells: {len(self.calculator.cells)}")
        
        # Calculate occupancy stats
        aircraft_per_cell = [len(cell.aircraft_records) for cell in self.calculator.cells.values()]
        print("\nOccupancy Statistics:")
        print(f"Mean aircraft per cell: {np.mean(aircraft_per_cell):.2f}")
        print(f"Max aircraft per cell: {np.max(aircraft_per_cell)}")
        print(f"Cells with multiple aircraft: {sum(n > 1 for n in aircraft_per_cell)}")

    def print_cell_contents(self, num_cells=3):
        """Print detailed contents of first n cells"""
        print(f"\nDetailed contents of first {num_cells} cells:")
        
        for i, (cell_key, cell) in enumerate(self.calculator.cells.items()):
            if i >= num_cells:
                break
                
            print(f"\nCell {i+1} at coordinates {cell_key}:")
            print(f"Boundaries:")
            print(f"  Longitude: {cell.x_min:.2f} to {cell.x_max:.2f}")
            print(f"  Latitude: {cell.y_min:.2f} to {cell.y_max:.2f}")
            print(f"  Altitude: {cell.z_min:.0f} to {cell.z_max:.0f} ft")
            print(f"  Time: {cell.t_min} to {cell.t_max}")
            print(f"Number of aircraft: {len(cell.aircraft_records)}")
            
            # Show sample of aircraft in cell
            print("\nSample aircraft records:")
            for j, aircraft in enumerate(cell.aircraft_records[:2]):  # Show first 2 aircraft
                print(f"  Aircraft {j+1}:")
                for key, value in aircraft.items():
                    print(f"    {key}: {value}")

    def get_cell_statistics(self):
        """Get various statistics about the cells"""
        stats = {}
        
        # Count aircraft by altitude layer
        alt_counts = {}
        for cell_key, cell in self.calculator.cells.items():
            alt_layer = cell_key[2]  # z-coordinate
            if alt_layer not in alt_counts:
                alt_counts[alt_layer] = 0
            alt_counts[alt_layer] += len(cell.aircraft_records)
        
        stats['aircraft_by_altitude'] = alt_counts
        
        # Count aircraft by time period
        time_counts = {}
        for cell_key, cell in self.calculator.cells.items():
            time_period = cell_key[3]  # t-coordinate
            if time_period not in time_counts:
                time_counts[time_period] = 0
            time_counts[time_period] += len(cell.aircraft_records)
            
        stats['aircraft_by_time'] = time_counts
        
        return stats

    def find_busiest_cells(self, top_n=5):
        """Find the cells with the most aircraft"""
        cell_occupancy = {
            cell_key: len(cell.aircraft_records) 
            for cell_key, cell in self.calculator.cells.items()
        }
        
        busiest_cells = sorted(cell_occupancy.items(), 
                             key=lambda x: x[1], 
                             reverse=True)[:top_n]
        
        print(f"\nTop {top_n} busiest cells:")
        for cell_key, count in busiest_cells:
            cell = self.calculator.cells[cell_key]
            print(f"\nCell at coordinates {cell_key}:")
            print(f"Number of aircraft: {count}")
            print(f"Altitude range: {cell.z_min:.0f} to {cell.z_max:.0f} ft")
            
            # Count different vertical states
            states = {'climb': 0, 'cruise': 0, 'descent': 0}
            for aircraft in cell.aircraft_records:
                states[aircraft['vertical_state']] += 1
            print("Vertical states:", states)

def analyze_trajectories(file_paths):
    """Analyze multiple trajectory files"""
    # Read and combine all trajectory files
    all_data = []
    for file_path in file_paths:
        df = pd.read_csv(file_path)
        df['flight_id'] = file_path.stem
        all_data.append(df)
    
    combined_data = pd.concat(all_data, ignore_index=True)
    
    # Create calculator and process data
    calculator = ComplexityCalculator()
    calculator.create_4d_grid(combined_data)
    
    # Create analyzer and show results
    analyzer = CellAnalyzer(calculator)
    
    # Print basic summary
    analyzer.print_cell_summary()
    
    # Show detailed contents of first few cells
    analyzer.print_cell_contents(num_cells=3)
    
    # Find busiest cells
    analyzer.find_busiest_cells(top_n=5)
    
    # Get statistics
    stats = analyzer.get_cell_statistics()
    
    # Print altitude distribution
    print("\nAircraft distribution by altitude layer:")
    for alt_layer, count in sorted(stats['aircraft_by_altitude'].items()):
        print(f"Layer {alt_layer}: {count} aircraft")
    
    # Print time distribution
    print("\nAircraft distribution by time period:")
    for time_period, count in sorted(stats['aircraft_by_time'].items()):
        print(f"Period {time_period}: {count} aircraft")

# Usage example:
if __name__ == "__main__":
    trajectory_files = list(Path("aircraft_trajectories").glob("SQ*.csv"))
    analyze_trajectories(trajectory_files)
